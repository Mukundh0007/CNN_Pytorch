# %%
! pip install -q kaggle

# %%
! gdown 1t-04GOyyrGQ9CA8zDGDpIweN43oSNR5O
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1t-04GOyyrGQ9CA8zDGDpIweN43oSNR5O
# To: /content/kaggle.json
# 100% 66.0/66.0 [00:00<00:00, 295kB/s]

# %%
! mkdir ~/.kaggle
! cp kaggle.json ~/.kaggle/

# %%
! chmod 600 ~/.kaggle/kaggle.json

# %%
! kaggle datasets download smaranjitghose/corn-or-maize-leaf-disease-dataset
# Out:
# Downloading corn-or-maize-leaf-disease-dataset.zip to /content
#  98% 157M/161M [00:00<00:00, 210MB/s]
# 100% 161M/161M [00:00<00:00, 180MB/s]

# %%
# !unzip /content/corn-or-maize-leaf-disease-dataset.zip
# Out:
# Archive:  /content/corn-or-maize-leaf-disease-dataset.zip
#   inflating: data/Blight/Corn_Blight (1).jpeg
#   inflating: data/Blight/Corn_Blight (1).jpg
#   inflating: data/Blight/Corn_Blight (10).jpg
#   inflating: data/Blight/Corn_Blight (100).jpg
#   inflating: data/Blight/Corn_Blight (1000).JPG
#   inflating: data/Blight/Corn_Blight (1001).JPG
#   inflating: data/Blight/Corn_Blight (1002).JPG
#   inflating: data/Blight/Corn_Blight (1003).JPG
#   inflating: data/Blight/Corn_Blight (1004).JPG
#   inflating: data/Blight/Corn_Blight (1005).JPG
#   inflating: data/Blight/Corn_Blight (1006).JPG
#   inflating: data/Blight/Corn_Blight (1007).JPG
#   inflating: data/Blight/Corn_Blight (1008).JPG
#   inflating: data/Blight/Corn_Blight (1009).JPG
#   inflating: data/Blight/Corn_Blight (101).jpg
#   inflating: data/Blight/Corn_Blight (1010).JPG
#   inflating: data/Blight/Corn_Blight (1011).jpg
#   inflating: data/Blight/Corn_Blight (1012).JPG
#   inflating: data/Blight/Corn_Blight (1013).JPG
#   inflating: data/Blight/Corn_Blight (1014).JPG
#   inflating: data/Blight/Corn_Blight (1015).jpg
#   inflating: data/Blight/Corn_Blight (1016).JPG
#   inflating: data/Blight/Corn_Blight (1017).JPG
#   inflating: data/Blight/Corn_Blight (1018).jpg
#   inflating: data/Blight/Corn_Blight (1019).JPG
#   inflating: data/Blight/Corn_Blight (102).jpg
#   inflating: data/Blight/Corn_Blight (1020).JPG
#   inflating: data/Blight/Corn_Blight (1021).JPG
#   inflating: data/Blight/Corn_Blight (1022).JPG
#   inflating: data/Blight/Corn_Blight (1023).JPG
#   inflating: data/Blight/Corn_Blight (1024).JPG
#   inflating: data/Blight/Corn_Blight (1025).JPG
#   inflating: data/Blight/Corn_Blight (1026).JPG
#   inflating: data/Blight/Corn_Blight (1027).JPG
#   inflating: data/Blight/Corn_Blight (1028).JPG
#   inflating: data/Blight/Corn_Blight (1029).JPG
#   inflating: data/Blight/Corn_Blight (103).jpg
#   inflating: data/Blight/Corn_Blight (1030).jpg
#   inflating: data/Blight/Corn_Blight (1031).JPG
#   inflating: data/Blight/Corn_Blight (1032).JPG
#   inflating: data/Blight/Corn_Blight (1033).jpg
#   inflating: data/Blight/Corn_Blight (1034).JPG
#   inflating: data/Blight/Corn_Blight (1035).JPG
#   inflating: data/Blight/Corn_Blight (1036).jpg
#   inflating: data/Blight/Corn_Blight (1037).JPG
#   inflating: data/Blight/Corn_Blight (1038).jpg
#   inflating: data/Blight/Corn_Blight (1039).jpg
#   inflating: data/Blight/Corn_Blight (104).jpg
#   inflating: data/Blight/Corn_Blight (1040).jpg
#   inflating: data/Blight/Corn_Blight (1041).JPG
#   inflating: data/Blight/Corn_Blight (1042).jpg
#   inflating: data/Blight/Corn_Blight (1043).JPG
#   inflating: data/Blight/Corn_Blight (1044).JPG
#   inflating: data/Blight/Corn_Blight (1045).JPG
#   inflating: data/Blight/Corn_Blight (1046).JPG
#   inflating: data/Blight/Corn_Blight (1047).JPG
#   inflating: data/Blight/Corn_Blight (1048).JPG
#   inflating: data/Blight/Corn_Blight (1049).JPG
#   inflating: data/Blight/Corn_Blight (105).jpg
#   inflating: data/Blight/Corn_Blight (1050).JPG
#   inflating: data/Blight/Corn_Blight (1051).JPG
#   inflating: data/Blight/Corn_Blight (1052).JPG
#   inflating: data/Blight/Corn_Blight (1053).JPG
#   inflating: data/Blight/Corn_Blight (1054).jpg
#   inflating: data/Blight/Corn_Blight (1055).JPG
#   inflating: data/Blight/Corn_Blight (1056).JPG
#   inflating: data/Blight/Corn_Blight (1057).JPG
#   inflating: data/Blight/Corn_Blight (1058).jpg
#   inflating: data/Blight/Corn_Blight (1059).JPG
#   inflating: data/Blight/Corn_Blight (106).jpg
#   inflating: data/Blight/Corn_Blight (1060).JPG
#   inflating: data/Blight/Corn_Blight (1061).JPG
#   inflating: data/Blight/Corn_Blight (1062).JPG
#   inflating: data/Blight/Corn_Blight (1063).JPG
#   inflating: data/Blight/Corn_Blight (1064).JPG
#   inflating: data/Blight/Corn_Blight (1065).JPG
#   inflating: data/Blight/Corn_Blight (1066).JPG
#   inflating: data/Blight/Corn_Blight (1067).JPG
#   inflating: data/Blight/Corn_Blight (1068).JPG
#   inflating: data/Blight/Corn_Blight (1069).JPG
#   inflating: data/Blight/Corn_Blight (107).jpg
#   inflating: data/Blight/Corn_Blight (1070).JPG
#   inflating: data/Blight/Corn_Blight (1071).JPG
#   inflating: data/Blight/Corn_Blight (1072).JPG
#   inflating: data/Blight/Corn_Blight (1073).jpg
#   inflating: data/Blight/Corn_Blight (1074).JPG
#   inflating: data/Blight/Corn_Blight (1075).JPG
#   inflating: data/Blight/Corn_Blight (1076).jpg
#   inflating: data/Blight/Corn_Blight (1077).JPG
#   inflating: data/Blight/Corn_Blight (1078).JPG
#   inflating: data/Blight/Corn_Blight (1079).JPG
#   inflating: data/Blight/Corn_Blight (108).jpg
#   inflating: data/Blight/Corn_Blight (1080).JPG
#   inflating: data/Blight/Corn_Blight (1081).jpg
#   inflating: data/Blight/Corn_Blight (1082).jpg
#   inflating: data/Blight/Corn_Blight (1083).JPG
#   inflating: data/Blight/Corn_Blight (1084).JPG
#   inflating: data/Blight/Corn_Blight (1085).JPG
#   inflating: data/Blight/Corn_Blight (1086).JPG
#   inflating: data/Blight/Corn_Blight (1087).JPG
#   inflating: data/Blight/Corn_Blight (1088).JPG
#   inflating: data/Blight/Corn_Blight (1089).JPG
#   inflating: data/Blight/Corn_Blight (109).jpg
#   inflating: data/Blight/Corn_Blight (1090).JPG
#   inflating: data/Blight/Corn_Blight (1091).JPG
#   inflating: data/Blight/Corn_Blight (1092).jpg
#   inflating: data/Blight/Corn_Blight (1093).JPG
#   inflating: data/Blight/Corn_Blight (1094).JPG
#   inflating: data/Blight/Corn_Blight (1095).JPG
#   inflating: data/Blight/Corn_Blight (1096).jpg
#   inflating: data/Blight/Corn_Blight (1097).jpg
#   inflating: data/Blight/Corn_Blight (1098).jpg
#   inflating: data/Blight/Corn_Blight (1099).jpg
#   inflating: data/Blight/Corn_Blight (11).jpg
#   inflating: data/Blight/Corn_Blight (110).jpg
#   inflating: data/Blight/Corn_Blight (1100).jpg
#   inflating: data/Blight/Corn_Blight (1101).jpg
#   inflating: data/Blight/Corn_Blight (1102).jpg
#   inflating: data/Blight/Corn_Blight (1103).jpg
#   inflating: data/Blight/Corn_Blight (1104).jpg
#   inflating: data/Blight/Corn_Blight (1105).jpg
#   inflating: data/Blight/Corn_Blight (1106).jpg
#   inflating: data/Blight/Corn_Blight (1107).jpg
#   inflating: data/Blight/Corn_Blight (1108).jpg
#   inflating: data/Blight/Corn_Blight (1109).jpg
#   inflating: data/Blight/Corn_Blight (111).JPG
#   inflating: data/Blight/Corn_Blight (1110).jpg
#   inflating: data/Blight/Corn_Blight (1111).jpg
#   inflating: data/Blight/Corn_Blight (1112).jpg
#   inflating: data/Blight/Corn_Blight (1113).jpg
#   inflating: data/Blight/Corn_Blight (1114).jpg
#   inflating: data/Blight/Corn_Blight (1115).jpg
#   inflating: data/Blight/Corn_Blight (1116).jpg
#   inflating: data/Blight/Corn_Blight (1117).jpg
#   inflating: data/Blight/Corn_Blight (1118).jpg
#   inflating: data/Blight/Corn_Blight (1119).jpg
#   inflating: data/Blight/Corn_Blight (112).JPG
#   inflating: data/Blight/Corn_Blight (1120).jpg
#   inflating: data/Blight/Corn_Blight (1121).jpg
#   inflating: data/Blight/Corn_Blight (1122).jpg
#   inflating: data/Blight/Corn_Blight (1123).jpg
#   inflating: data/Blight/Corn_Blight (1124).jpg
#   inflating: data/Blight/Corn_Blight (1125).jpg
#   inflating: data/Blight/Corn_Blight (1126).jpg
#   inflating: data/Blight/Corn_Blight (1127).jpg
#   inflating: data/Blight/Corn_Blight (1128).jpg
#   inflating: data/Blight/Corn_Blight (1129).jpg
#   inflating: data/Blight/Corn_Blight (113).JPG
#   inflating: data/Blight/Corn_Blight (1130).jpg
#   inflating: data/Blight/Corn_Blight (1131).jpg
#   inflating: data/Blight/Corn_Blight (1132).jpg
#   inflating: data/Blight/Corn_Blight (1133).jpg
#   inflating: data/Blight/Corn_Blight (1134).jpg
#   inflating: data/Blight/Corn_Blight (1135).jpg
#   inflating: data/Blight/Corn_Blight (1136).jpg
#   inflating: data/Blight/Corn_Blight (1137).jpg
#   inflating: data/Blight/Corn_Blight (1138).jpg
#   inflating: data/Blight/Corn_Blight (1139).jpg
#   inflating: data/Blight/Corn_Blight (114).JPG
#   inflating: data/Blight/Corn_Blight (1140).jpg
#   inflating: data/Blight/Corn_Blight (1141).jpg
#   inflating: data/Blight/Corn_Blight (1142).jpg
#   inflating: data/Blight/Corn_Blight (1143).jpg
#   inflating: data/Blight/Corn_Blight (1144).jpg
#   inflating: data/Blight/Corn_Blight (1145).jpg
#   inflating: data/Blight/Corn_Blight (115).JPG
#   inflating: data/Blight/Corn_Blight (116).JPG
#   inflating: data/Blight/Corn_Blight (117).JPG
#   inflating: data/Blight/Corn_Blight (118).JPG
#   inflating: data/Blight/Corn_Blight (119).JPG
#   inflating: data/Blight/Corn_Blight (12).jpg
#   inflating: data/Blight/Corn_Blight (120).JPG
#   inflating: data/Blight/Corn_Blight (121).JPG
#   inflating: data/Blight/Corn_Blight (122).JPG
#   inflating: data/Blight/Corn_Blight (123).JPG
#   inflating: data/Blight/Corn_Blight (124).JPG
#   inflating: data/Blight/Corn_Blight (125).jpg
#   inflating: data/Blight/Corn_Blight (126).JPG
#   inflating: data/Blight/Corn_Blight (127).JPG
#   inflating: data/Blight/Corn_Blight (128).JPG
#   inflating: data/Blight/Corn_Blight (129).JPG
#   inflating: data/Blight/Corn_Blight (13).jpg
#   inflating: data/Blight/Corn_Blight (130).jpg
#   inflating: data/Blight/Corn_Blight (131).JPG
#   inflating: data/Blight/Corn_Blight (132).JPG
#   inflating: data/Blight/Corn_Blight (133).JPG
#   inflating: data/Blight/Corn_Blight (134).jpg
#   inflating: data/Blight/Corn_Blight (135).JPG
#   inflating: data/Blight/Corn_Blight (136).JPG
#   inflating: data/Blight/Corn_Blight (137).JPG
#   inflating: data/Blight/Corn_Blight (138).JPG
#   inflating: data/Blight/Corn_Blight (139).jpg
#   inflating: data/Blight/Corn_Blight (14).jpg
#   inflating: data/Blight/Corn_Blight (140).JPG
#   inflating: data/Blight/Corn_Blight (141).JPG
#   inflating: data/Blight/Corn_Blight (142).JPG
#   inflating: data/Blight/Corn_Blight (143).JPG
#   inflating: data/Blight/Corn_Blight (144).jpg
#   inflating: data/Blight/Corn_Blight (145).JPG
#   inflating: data/Blight/Corn_Blight (146).JPG
#   inflating: data/Blight/Corn_Blight (147).jpg
#   inflating: data/Blight/Corn_Blight (148).JPG
#   inflating: data/Blight/Corn_Blight (149).JPG
#   inflating: data/Blight/Corn_Blight (15).jpg
#   inflating: data/Blight/Corn_Blight (150).JPG
#   inflating: data/Blight/Corn_Blight (151).JPG
#   inflating: data/Blight/Corn_Blight (152).JPG
#   inflating: data/Blight/Corn_Blight (153).JPG
#   inflating: data/Blight/Corn_Blight (154).JPG
#   inflating: data/Blight/Corn_Blight (155).JPG
#   inflating: data/Blight/Corn_Blight (156).JPG
#   inflating: data/Blight/Corn_Blight (157).JPG
#   inflating: data/Blight/Corn_Blight (158).JPG
#   inflating: data/Blight/Corn_Blight (159).JPG
#   inflating: data/Blight/Corn_Blight (16).jpg
#   inflating: data/Blight/Corn_Blight (160).JPG
#   inflating: data/Blight/Corn_Blight (161).JPG
#   inflating: data/Blight/Corn_Blight (162).jpg
#   inflating: data/Blight/Corn_Blight (163).JPG
#   inflating: data/Blight/Corn_Blight (164).JPG
#   inflating: data/Blight/Corn_Blight (165).jpg
#   inflating: data/Blight/Corn_Blight (166).JPG
#   inflating: data/Blight/Corn_Blight (167).JPG
#   inflating: data/Blight/Corn_Blight (168).JPG
#   inflating: data/Blight/Corn_Blight (169).JPG
#   inflating: data/Blight/Corn_Blight (17).jpg
#   inflating: data/Blight/Corn_Blight (170).JPG
#   inflating: data/Blight/Corn_Blight (171).JPG
#   inflating: data/Blight/Corn_Blight (172).JPG
#   inflating: data/Blight/Corn_Blight (173).JPG
#   inflating: data/Blight/Corn_Blight (174).JPG
#   inflating: data/Blight/Corn_Blight (175).jpg
#   inflating: data/Blight/Corn_Blight (176).jpg
#   inflating: data/Blight/Corn_Blight (177).JPG
#   inflating: data/Blight/Corn_Blight (178).jpg
#   inflating: data/Blight/Corn_Blight (179).JPG
#   inflating: data/Blight/Corn_Blight (18).jpg
#   inflating: data/Blight/Corn_Blight (180).JPG
#   inflating: data/Blight/Corn_Blight (181).JPG
#   inflating: data/Blight/Corn_Blight (182).JPG
#   inflating: data/Blight/Corn_Blight (183).JPG
#   inflating: data/Blight/Corn_Blight (184).JPG
#   inflating: data/Blight/Corn_Blight (185).JPG
#   inflating: data/Blight/Corn_Blight (186).JPG
#   inflating: data/Blight/Corn_Blight (187).JPG
#   inflating: data/Blight/Corn_Blight (188).JPG
#   inflating: data/Blight/Corn_Blight (189).JPG
#   inflating: data/Blight/Corn_Blight (19).jpg
#   inflating: data/Blight/Corn_Blight (190).JPG
#   inflating: data/Blight/Corn_Blight (191).JPG
#   inflating: data/Blight/Corn_Blight (192).JPG
#   inflating: data/Blight/Corn_Blight (193).JPG
#   inflating: data/Blight/Corn_Blight (194).JPG
#   inflating: data/Blight/Corn_Blight (195).JPG
#   inflating: data/Blight/Corn_Blight (196).JPG
#   inflating: data/Blight/Corn_Blight (197).JPG
#   inflating: data/Blight/Corn_Blight (198).JPG
#   inflating: data/Blight/Corn_Blight (199).JPG
#   inflating: data/Blight/Corn_Blight (2).jpg
#   inflating: data/Blight/Corn_Blight (20).jpg
#   inflating: data/Blight/Corn_Blight (200).JPG
#   inflating: data/Blight/Corn_Blight (201).JPG
#   inflating: data/Blight/Corn_Blight (202).JPG
#   inflating: data/Blight/Corn_Blight (203).JPG
#   inflating: data/Blight/Corn_Blight (204).jpg
#   inflating: data/Blight/Corn_Blight (205).JPG
#   inflating: data/Blight/Corn_Blight (206).JPG
#   inflating: data/Blight/Corn_Blight (207).JPG
#   inflating: data/Blight/Corn_Blight (208).jpg
#   inflating: data/Blight/Corn_Blight (209).JPG
#   inflating: data/Blight/Corn_Blight (21).jpg
#   inflating: data/Blight/Corn_Blight (210).JPG
#   inflating: data/Blight/Corn_Blight (211).JPG
#   inflating: data/Blight/Corn_Blight (212).JPG
#   inflating: data/Blight/Corn_Blight (213).JPG
#   inflating: data/Blight/Corn_Blight (214).JPG
#   inflating: data/Blight/Corn_Blight (215).JPG
#   inflating: data/Blight/Corn_Blight (216).JPG
#   inflating: data/Blight/Corn_Blight (217).JPG
#   inflating: data/Blight/Corn_Blight (218).JPG
#   inflating: data/Blight/Corn_Blight (219).JPG
#   inflating: data/Blight/Corn_Blight (22).jpg
#   inflating: data/Blight/Corn_Blight (220).JPG
#   inflating: data/Blight/Corn_Blight (221).JPG
#   inflating: data/Blight/Corn_Blight (222).JPG
#   inflating: data/Blight/Corn_Blight (223).JPG
#   inflating: data/Blight/Corn_Blight (224).JPG
#   inflating: data/Blight/Corn_Blight (225).JPG
#   inflating: data/Blight/Corn_Blight (226).JPG
#   inflating: data/Blight/Corn_Blight (227).JPG
#   inflating: data/Blight/Corn_Blight (228).JPG
#   inflating: data/Blight/Corn_Blight (229).JPG
#   inflating: data/Blight/Corn_Blight (23).jpg
#   inflating: data/Blight/Corn_Blight (230).JPG
#   inflating: data/Blight/Corn_Blight (231).JPG
#   inflating: data/Blight/Corn_Blight (232).JPG
#   inflating: data/Blight/Corn_Blight (233).JPG
#   inflating: data/Blight/Corn_Blight (234).JPG
#   inflating: data/Blight/Corn_Blight (235).JPG
#   inflating: data/Blight/Corn_Blight (236).JPG
#   inflating: data/Blight/Corn_Blight (237).JPG
#   inflating: data/Blight/Corn_Blight (238).JPG
#   inflating: data/Blight/Corn_Blight (239).JPG
#   inflating: data/Blight/Corn_Blight (24).jpg
#   inflating: data/Blight/Corn_Blight (240).JPG
#   inflating: data/Blight/Corn_Blight (241).JPG
#   inflating: data/Blight/Corn_Blight (242).JPG
#   inflating: data/Blight/Corn_Blight (243).JPG
#   inflating: data/Blight/Corn_Blight (244).JPG
#   inflating: data/Blight/Corn_Blight (245).JPG
#   inflating: data/Blight/Corn_Blight (246).jpg
#   inflating: data/Blight/Corn_Blight (247).JPG
#   inflating: data/Blight/Corn_Blight (248).JPG
#   inflating: data/Blight/Corn_Blight (249).JPG
#   inflating: data/Blight/Corn_Blight (25).jpg
#   inflating: data/Blight/Corn_Blight (250).JPG
#   inflating: data/Blight/Corn_Blight (251).JPG
#   inflating: data/Blight/Corn_Blight (252).JPG
#   inflating: data/Blight/Corn_Blight (253).JPG
#   inflating: data/Blight/Corn_Blight (254).JPG
#   inflating: data/Blight/Corn_Blight (255).JPG
#   inflating: data/Blight/Corn_Blight (256).JPG
#   inflating: data/Blight/Corn_Blight (257).JPG
#   inflating: data/Blight/Corn_Blight (258).JPG
#   inflating: data/Blight/Corn_Blight (259).jpg
#   inflating: data/Blight/Corn_Blight (26).jpg
#   inflating: data/Blight/Corn_Blight (260).JPG
#   inflating: data/Blight/Corn_Blight (261).JPG
#   inflating: data/Blight/Corn_Blight (262).JPG
#   inflating: data/Blight/Corn_Blight (263).JPG
#   inflating: data/Blight/Corn_Blight (264).jpg
#   inflating: data/Blight/Corn_Blight (265).JPG
#   inflating: data/Blight/Corn_Blight (266).JPG
#   inflating: data/Blight/Corn_Blight (267).JPG
#   inflating: data/Blight/Corn_Blight (268).JPG
#   inflating: data/Blight/Corn_Blight (269).JPG
#   inflating: data/Blight/Corn_Blight (27).jpg
#   inflating: data/Blight/Corn_Blight (270).JPG
#   inflating: data/Blight/Corn_Blight (271).JPG
#   inflating: data/Blight/Corn_Blight (272).JPG
#   inflating: data/Blight/Corn_Blight (273).JPG
#   inflating: data/Blight/Corn_Blight (274).JPG
#   inflating: data/Blight/Corn_Blight (275).jpg
#   inflating: data/Blight/Corn_Blight (276).JPG
#   inflating: data/Blight/Corn_Blight (277).JPG
#   inflating: data/Blight/Corn_Blight (278).JPG
#   inflating: data/Blight/Corn_Blight (279).JPG
#   inflating: data/Blight/Corn_Blight (28).jpg
#   inflating: data/Blight/Corn_Blight (280).JPG
#   inflating: data/Blight/Corn_Blight (281).JPG
#   inflating: data/Blight/Corn_Blight (282).JPG
#   inflating: data/Blight/Corn_Blight (283).JPG
#   inflating: data/Blight/Corn_Blight (284).jpg
#   inflating: data/Blight/Corn_Blight (285).JPG
#   inflating: data/Blight/Corn_Blight (286).jpg
#   inflating: data/Blight/Corn_Blight (287).JPG
#   inflating: data/Blight/Corn_Blight (288).JPG
#   inflating: data/Blight/Corn_Blight (289).JPG
#   inflating: data/Blight/Corn_Blight (29).jpg
#   inflating: data/Blight/Corn_Blight (290).JPG
#   inflating: data/Blight/Corn_Blight (291).JPG
#   inflating: data/Blight/Corn_Blight (292).JPG
#   inflating: data/Blight/Corn_Blight (293).JPG
#   inflating: data/Blight/Corn_Blight (294).JPG
#   inflating: data/Blight/Corn_Blight (295).JPG
#   inflating: data/Blight/Corn_Blight (296).JPG
#   inflating: data/Blight/Corn_Blight (297).JPG
#   inflating: data/Blight/Corn_Blight (298).JPG
#   inflating: data/Blight/Corn_Blight (299).JPG
#   inflating: data/Blight/Corn_Blight (3).jpg
#   inflating: data/Blight/Corn_Blight (30).jpg
#   inflating: data/Blight/Corn_Blight (300).JPG
#   inflating: data/Blight/Corn_Blight (301).JPG
#   inflating: data/Blight/Corn_Blight (302).JPG
#   inflating: data/Blight/Corn_Blight (303).jpg
#   inflating: data/Blight/Corn_Blight (304).jpg
#   inflating: data/Blight/Corn_Blight (305).JPG
#   inflating: data/Blight/Corn_Blight (306).JPG
#   inflating: data/Blight/Corn_Blight (307).jpg
#   inflating: data/Blight/Corn_Blight (308).JPG
#   inflating: data/Blight/Corn_Blight (309).jpg
#   inflating: data/Blight/Corn_Blight (31).jpg
#   inflating: data/Blight/Corn_Blight (310).JPG
#   inflating: data/Blight/Corn_Blight (311).JPG
#   inflating: data/Blight/Corn_Blight (312).JPG
#   inflating: data/Blight/Corn_Blight (313).JPG
#   inflating: data/Blight/Corn_Blight (314).JPG
#   inflating: data/Blight/Corn_Blight (315).JPG
#   inflating: data/Blight/Corn_Blight (316).JPG
#   inflating: data/Blight/Corn_Blight (317).jpg
#   inflating: data/Blight/Corn_Blight (318).JPG
#   inflating: data/Blight/Corn_Blight (319).JPG
#   inflating: data/Blight/Corn_Blight (32).jpg
#   inflating: data/Blight/Corn_Blight (320).JPG
#   inflating: data/Blight/Corn_Blight (321).JPG
#   inflating: data/Blight/Corn_Blight (322).JPG
#   inflating: data/Blight/Corn_Blight (323).jpg
#   inflating: data/Blight/Corn_Blight (324).JPG
#   inflating: data/Blight/Corn_Blight (325).JPG
#   inflating: data/Blight/Corn_Blight (326).JPG
#   inflating: data/Blight/Corn_Blight (327).JPG
#   inflating: data/Blight/Corn_Blight (328).JPG
#   inflating: data/Blight/Corn_Blight (329).JPG
#   inflating: data/Blight/Corn_Blight (33).jpg
#   inflating: data/Blight/Corn_Blight (330).JPG
#   inflating: data/Blight/Corn_Blight (331).JPG
#   inflating: data/Blight/Corn_Blight (332).JPG
#   inflating: data/Blight/Corn_Blight (333).JPG
#   inflating: data/Blight/Corn_Blight (334).JPG
#   inflating: data/Blight/Corn_Blight (335).JPG
#   inflating: data/Blight/Corn_Blight (336).JPG
#   inflating: data/Blight/Corn_Blight (337).JPG
#   inflating: data/Blight/Corn_Blight (338).JPG
#   inflating: data/Blight/Corn_Blight (339).jpg
#   inflating: data/Blight/Corn_Blight (34).jpg
#   inflating: data/Blight/Corn_Blight (340).JPG
#   inflating: data/Blight/Corn_Blight (341).JPG
#   inflating: data/Blight/Corn_Blight (342).JPG
#   inflating: data/Blight/Corn_Blight (343).JPG
#   inflating: data/Blight/Corn_Blight (344).JPG
#   inflating: data/Blight/Corn_Blight (345).JPG
#   inflating: data/Blight/Corn_Blight (346).JPG
#   inflating: data/Blight/Corn_Blight (347).JPG
#   inflating: data/Blight/Corn_Blight (348).jpg
#   inflating: data/Blight/Corn_Blight (349).JPG
#   inflating: data/Blight/Corn_Blight (35).jpg
#   inflating: data/Blight/Corn_Blight (350).JPG
#   inflating: data/Blight/Corn_Blight (351).JPG
#   inflating: data/Blight/Corn_Blight (352).JPG
#   inflating: data/Blight/Corn_Blight (353).JPG
#   inflating: data/Blight/Corn_Blight (354).JPG
#   inflating: data/Blight/Corn_Blight (355).JPG
#   inflating: data/Blight/Corn_Blight (356).JPG
#   inflating: data/Blight/Corn_Blight (357).JPG
#   inflating: data/Blight/Corn_Blight (358).JPG
#   inflating: data/Blight/Corn_Blight (359).JPG
#   inflating: data/Blight/Corn_Blight (36).jpg
#   inflating: data/Blight/Corn_Blight (360).JPG
#   inflating: data/Blight/Corn_Blight (361).JPG
#   inflating: data/Blight/Corn_Blight (362).JPG
#   inflating: data/Blight/Corn_Blight (363).JPG
#   inflating: data/Blight/Corn_Blight (364).JPG
#   inflating: data/Blight/Corn_Blight (365).JPG
#   inflating: data/Blight/Corn_Blight (366).JPG
#   inflating: data/Blight/Corn_Blight (367).JPG
#   inflating: data/Blight/Corn_Blight (368).JPG
#   inflating: data/Blight/Corn_Blight (369).JPG
#   inflating: data/Blight/Corn_Blight (37).jpg
#   inflating: data/Blight/Corn_Blight (370).JPG
#   inflating: data/Blight/Corn_Blight (371).JPG
#   inflating: data/Blight/Corn_Blight (372).JPG
#   inflating: data/Blight/Corn_Blight (373).JPG
#   inflating: data/Blight/Corn_Blight (374).JPG
#   inflating: data/Blight/Corn_Blight (375).JPG
#   inflating: data/Blight/Corn_Blight (376).JPG
#   inflating: data/Blight/Corn_Blight (377).JPG
#   inflating: data/Blight/Corn_Blight (378).JPG
#   inflating: data/Blight/Corn_Blight (379).JPG
#   inflating: data/Blight/Corn_Blight (38).jpg
#   inflating: data/Blight/Corn_Blight (380).JPG
#   inflating: data/Blight/Corn_Blight (381).JPG
#   inflating: data/Blight/Corn_Blight (382).JPG
#   inflating: data/Blight/Corn_Blight (383).JPG
#   inflating: data/Blight/Corn_Blight (384).jpg
#   inflating: data/Blight/Corn_Blight (385).JPG
#   inflating: data/Blight/Corn_Blight (386).JPG
#   inflating: data/Blight/Corn_Blight (387).JPG
#   inflating: data/Blight/Corn_Blight (388).JPG
#   inflating: data/Blight/Corn_Blight (389).JPG
#   inflating: data/Blight/Corn_Blight (39).jpg
#   inflating: data/Blight/Corn_Blight (390).JPG
#   inflating: data/Blight/Corn_Blight (391).JPG
#   inflating: data/Blight/Corn_Blight (392).JPG
#   inflating: data/Blight/Corn_Blight (393).JPG
#   inflating: data/Blight/Corn_Blight (394).JPG
#   inflating: data/Blight/Corn_Blight (395).JPG
#   inflating: data/Blight/Corn_Blight (396).JPG
#   inflating: data/Blight/Corn_Blight (397).JPG
#   inflating: data/Blight/Corn_Blight (398).JPG
#   inflating: data/Blight/Corn_Blight (399).jpg
#   inflating: data/Blight/Corn_Blight (4).jpg
#   inflating: data/Blight/Corn_Blight (40).jpg
#   inflating: data/Blight/Corn_Blight (400).JPG
#   inflating: data/Blight/Corn_Blight (401).JPG
#   inflating: data/Blight/Corn_Blight (402).JPG
#   inflating: data/Blight/Corn_Blight (403).JPG
#   inflating: data/Blight/Corn_Blight (404).jpg
#   inflating: data/Blight/Corn_Blight (405).JPG
#   inflating: data/Blight/Corn_Blight (406).JPG
#   inflating: data/Blight/Corn_Blight (407).JPG
#   inflating: data/Blight/Corn_Blight (408).JPG
#   inflating: data/Blight/Corn_Blight (409).JPG
#   inflating: data/Blight/Corn_Blight (41).jpg
#   inflating: data/Blight/Corn_Blight (410).JPG
#   inflating: data/Blight/Corn_Blight (411).JPG
#   inflating: data/Blight/Corn_Blight (412).JPG
#   inflating: data/Blight/Corn_Blight (413).JPG
#   inflating: data/Blight/Corn_Blight (414).JPG
#   inflating: data/Blight/Corn_Blight (415).jpg
#   inflating: data/Blight/Corn_Blight (416).JPG
#   inflating: data/Blight/Corn_Blight (417).JPG
#   inflating: data/Blight/Corn_Blight (418).JPG
#   inflating: data/Blight/Corn_Blight (419).JPG
#   inflating: data/Blight/Corn_Blight (42).jpg
#   inflating: data/Blight/Corn_Blight (420).JPG
#   inflating: data/Blight/Corn_Blight (421).JPG
#   inflating: data/Blight/Corn_Blight (422).jpg
#   inflating: data/Blight/Corn_Blight (423).jpg
#   inflating: data/Blight/Corn_Blight (424).JPG
#   inflating: data/Blight/Corn_Blight (425).JPG
#   inflating: data/Blight/Corn_Blight (426).JPG
#   inflating: data/Blight/Corn_Blight (427).JPG
#   inflating: data/Blight/Corn_Blight (428).JPG
#   inflating: data/Blight/Corn_Blight (429).JPG
#   inflating: data/Blight/Corn_Blight (43).jpg
#   inflating: data/Blight/Corn_Blight (430).JPG
#   inflating: data/Blight/Corn_Blight (431).JPG
#   inflating: data/Blight/Corn_Blight (432).JPG
#   inflating: data/Blight/Corn_Blight (433).jpg
#   inflating: data/Blight/Corn_Blight (434).JPG
#   inflating: data/Blight/Corn_Blight (435).JPG
#   inflating: data/Blight/Corn_Blight (436).JPG
#   inflating: data/Blight/Corn_Blight (437).JPG
#   inflating: data/Blight/Corn_Blight (438).jpg
#   inflating: data/Blight/Corn_Blight (439).jpg
#   inflating: data/Blight/Corn_Blight (44).jpg
#   inflating: data/Blight/Corn_Blight (440).JPG
#   inflating: data/Blight/Corn_Blight (441).JPG
#   inflating: data/Blight/Corn_Blight (442).JPG
#   inflating: data/Blight/Corn_Blight (443).JPG
#   inflating: data/Blight/Corn_Blight (444).JPG
#   inflating: data/Blight/Corn_Blight (445).JPG
#   inflating: data/Blight/Corn_Blight (446).JPG
#   inflating: data/Blight/Corn_Blight (447).JPG
#   inflating: data/Blight/Corn_Blight (448).JPG
#   inflating: data/Blight/Corn_Blight (449).JPG
#   inflating: data/Blight/Corn_Blight (45).jpg
#   inflating: data/Blight/Corn_Blight (450).JPG
#   inflating: data/Blight/Corn_Blight (451).JPG
#   inflating: data/Blight/Corn_Blight (452).JPG
#   inflating: data/Blight/Corn_Blight (453).JPG
#   inflating: data/Blight/Corn_Blight (454).JPG
#   inflating: data/Blight/Corn_Blight (455).JPG
#   inflating: data/Blight/Corn_Blight (456).JPG
#   inflating: data/Blight/Corn_Blight (457).JPG
#   inflating: data/Blight/Corn_Blight (458).JPG
#   inflating: data/Blight/Corn_Blight (459).JPG
#   inflating: data/Blight/Corn_Blight (46).jpg
#   inflating: data/Blight/Corn_Blight (460).JPG
#   inflating: data/Blight/Corn_Blight (461).JPG
#   inflating: data/Blight/Corn_Blight (462).JPG
#   inflating: data/Blight/Corn_Blight (463).JPG
#   inflating: data/Blight/Corn_Blight (464).JPG
#   inflating: data/Blight/Corn_Blight (465).JPG
#   inflating: data/Blight/Corn_Blight (466).JPG
#   inflating: data/Blight/Corn_Blight (467).JPG
#   inflating: data/Blight/Corn_Blight (468).JPG
#   inflating: data/Blight/Corn_Blight (469).JPG
#   inflating: data/Blight/Corn_Blight (47).jpg
#   inflating: data/Blight/Corn_Blight (470).JPG
#   inflating: data/Blight/Corn_Blight (471).JPG
#   inflating: data/Blight/Corn_Blight (472).JPG
#   inflating: data/Blight/Corn_Blight (473).JPG
#   inflating: data/Blight/Corn_Blight (474).JPG
#   inflating: data/Blight/Corn_Blight (475).JPG
#   inflating: data/Blight/Corn_Blight (476).JPG
#   inflating: data/Blight/Corn_Blight (477).JPG
#   inflating: data/Blight/Corn_Blight (478).JPG
#   inflating: data/Blight/Corn_Blight (479).JPG
#   inflating: data/Blight/Corn_Blight (48).jpg
#   inflating: data/Blight/Corn_Blight (480).JPG
#   inflating: data/Blight/Corn_Blight (481).JPG
#   inflating: data/Blight/Corn_Blight (482).JPG
#   inflating: data/Blight/Corn_Blight (483).JPG
#   inflating: data/Blight/Corn_Blight (484).JPG
#   inflating: data/Blight/Corn_Blight (485).JPG
#   inflating: data/Blight/Corn_Blight (486).JPG
#   inflating: data/Blight/Corn_Blight (487).JPG
#   inflating: data/Blight/Corn_Blight (488).JPG
#   inflating: data/Blight/Corn_Blight (489).JPG
#   inflating: data/Blight/Corn_Blight (49).jpg
#   inflating: data/Blight/Corn_Blight (490).jpg
#   inflating: data/Blight/Corn_Blight (491).jpg
#   inflating: data/Blight/Corn_Blight (492).JPG
#   inflating: data/Blight/Corn_Blight (493).JPG
#   inflating: data/Blight/Corn_Blight (494).JPG
#   inflating: data/Blight/Corn_Blight (495).JPG
#   inflating: data/Blight/Corn_Blight (496).JPG
#   inflating: data/Blight/Corn_Blight (497).JPG
#   inflating: data/Blight/Corn_Blight (498).jpg
#   inflating: data/Blight/Corn_Blight (499).JPG
#   inflating: data/Blight/Corn_Blight (5).jpg
#   inflating: data/Blight/Corn_Blight (50).jpg
#   inflating: data/Blight/Corn_Blight (500).JPG
#   inflating: data/Blight/Corn_Blight (501).JPG
#   inflating: data/Blight/Corn_Blight (502).JPG
#   inflating: data/Blight/Corn_Blight (503).JPG
#   inflating: data/Blight/Corn_Blight (504).JPG
#   inflating: data/Blight/Corn_Blight (505).JPG
#   inflating: data/Blight/Corn_Blight (506).JPG
#   inflating: data/Blight/Corn_Blight (507).JPG
#   inflating: data/Blight/Corn_Blight (508).JPG
#   inflating: data/Blight/Corn_Blight (509).JPG
#   inflating: data/Blight/Corn_Blight (51).jpg
#   inflating: data/Blight/Corn_Blight (510).jpg
#   inflating: data/Blight/Corn_Blight (511).JPG
#   inflating: data/Blight/Corn_Blight (512).JPG
#   inflating: data/Blight/Corn_Blight (513).JPG
#   inflating: data/Blight/Corn_Blight (514).JPG
#   inflating: data/Blight/Corn_Blight (515).JPG
#   inflating: data/Blight/Corn_Blight (516).JPG
#   inflating: data/Blight/Corn_Blight (517).JPG
#   inflating: data/Blight/Corn_Blight (518).JPG
#   inflating: data/Blight/Corn_Blight (519).JPG
#   inflating: data/Blight/Corn_Blight (52).jpg
#   inflating: data/Blight/Corn_Blight (520).JPG
#   inflating: data/Blight/Corn_Blight (521).JPG
#   inflating: data/Blight/Corn_Blight (522).JPG
#   inflating: data/Blight/Corn_Blight (523).JPG
#   inflating: data/Blight/Corn_Blight (524).JPG
#   inflating: data/Blight/Corn_Blight (525).JPG
#   inflating: data/Blight/Corn_Blight (526).JPG
#   inflating: data/Blight/Corn_Blight (527).JPG
#   inflating: data/Blight/Corn_Blight (528).JPG
#   inflating: data/Blight/Corn_Blight (529).JPG
#   inflating: data/Blight/Corn_Blight (53).jpg
#   inflating: data/Blight/Corn_Blight (530).JPG
#   inflating: data/Blight/Corn_Blight (531).JPG
#   inflating: data/Blight/Corn_Blight (532).JPG
#   inflating: data/Blight/Corn_Blight (533).JPG
#   inflating: data/Blight/Corn_Blight (534).JPG
#   inflating: data/Blight/Corn_Blight (535).JPG
#   inflating: data/Blight/Corn_Blight (536).JPG
#   inflating: data/Blight/Corn_Blight (537).JPG
#   inflating: data/Blight/Corn_Blight (538).JPG
#   inflating: data/Blight/Corn_Blight (539).JPG
#   inflating: data/Blight/Corn_Blight (54).jpg
#   inflating: data/Blight/Corn_Blight (540).jpg
#   inflating: data/Blight/Corn_Blight (541).jpg
#   inflating: data/Blight/Corn_Blight (542).jpg
#   inflating: data/Blight/Corn_Blight (543).JPG
#   inflating: data/Blight/Corn_Blight (544).JPG
#   inflating: data/Blight/Corn_Blight (545).JPG
#   inflating: data/Blight/Corn_Blight (546).JPG
#   inflating: data/Blight/Corn_Blight (547).JPG
#   inflating: data/Blight/Corn_Blight (548).JPG
#   inflating: data/Blight/Corn_Blight (549).JPG
#   inflating: data/Blight/Corn_Blight (55).jpg
#   inflating: data/Blight/Corn_Blight (550).jpg
#   inflating: data/Blight/Corn_Blight (551).JPG
#   inflating: data/Blight/Corn_Blight (552).JPG
#   inflating: data/Blight/Corn_Blight (553).JPG
#   inflating: data/Blight/Corn_Blight (554).JPG
#   inflating: data/Blight/Corn_Blight (555).JPG
#   inflating: data/Blight/Corn_Blight (556).JPG
#   inflating: data/Blight/Corn_Blight (557).jpg
#   inflating: data/Blight/Corn_Blight (558).JPG
#   inflating: data/Blight/Corn_Blight (559).JPG
#   inflating: data/Blight/Corn_Blight (56).jpg
#   inflating: data/Blight/Corn_Blight (560).JPG
#   inflating: data/Blight/Corn_Blight (561).jpg
#   inflating: data/Blight/Corn_Blight (562).JPG
#   inflating: data/Blight/Corn_Blight (563).JPG
#   inflating: data/Blight/Corn_Blight (564).JPG
#   inflating: data/Blight/Corn_Blight (565).JPG
#   inflating: data/Blight/Corn_Blight (566).JPG
#   inflating: data/Blight/Corn_Blight (567).JPG
#   inflating: data/Blight/Corn_Blight (568).JPG
#   inflating: data/Blight/Corn_Blight (569).JPG
#   inflating: data/Blight/Corn_Blight (57).jpg
#   inflating: data/Blight/Corn_Blight (570).JPG
#   inflating: data/Blight/Corn_Blight (571).JPG
#   inflating: data/Blight/Corn_Blight (572).JPG
#   inflating: data/Blight/Corn_Blight (573).JPG
#   inflating: data/Blight/Corn_Blight (574).JPG
#   inflating: data/Blight/Corn_Blight (575).JPG
#   inflating: data/Blight/Corn_Blight (576).JPG
#   inflating: data/Blight/Corn_Blight (577).JPG
#   inflating: data/Blight/Corn_Blight (578).JPG
#   inflating: data/Blight/Corn_Blight (579).JPG
#   inflating: data/Blight/Corn_Blight (58).jpg
#   inflating: data/Blight/Corn_Blight (580).jpg
#   inflating: data/Blight/Corn_Blight (581).JPG
#   inflating: data/Blight/Corn_Blight (582).jpg
#   inflating: data/Blight/Corn_Blight (583).JPG
#   inflating: data/Blight/Corn_Blight (584).JPG
#   inflating: data/Blight/Corn_Blight (585).JPG
#   inflating: data/Blight/Corn_Blight (586).JPG
#   inflating: data/Blight/Corn_Blight (587).JPG
#   inflating: data/Blight/Corn_Blight (588).JPG
#   inflating: data/Blight/Corn_Blight (589).JPG
#   inflating: data/Blight/Corn_Blight (59).jpg
#   inflating: data/Blight/Corn_Blight (590).JPG
#   inflating: data/Blight/Corn_Blight (591).jpg
#   inflating: data/Blight/Corn_Blight (592).JPG
#   inflating: data/Blight/Corn_Blight (593).JPG
#   inflating: data/Blight/Corn_Blight (594).JPG
#   inflating: data/Blight/Corn_Blight (595).JPG
#   inflating: data/Blight/Corn_Blight (596).JPG
#   inflating: data/Blight/Corn_Blight (597).jpg
#   inflating: data/Blight/Corn_Blight (598).JPG
#   inflating: data/Blight/Corn_Blight (599).JPG
#   inflating: data/Blight/Corn_Blight (6).jpg
#   inflating: data/Blight/Corn_Blight (60).jpg
#   inflating: data/Blight/Corn_Blight (600).jpg
#   inflating: data/Blight/Corn_Blight (601).jpg
#   inflating: data/Blight/Corn_Blight (602).JPG
#   inflating: data/Blight/Corn_Blight (603).JPG
#   inflating: data/Blight/Corn_Blight (604).JPG
#   inflating: data/Blight/Corn_Blight (605).JPG
#   inflating: data/Blight/Corn_Blight (606).JPG
#   inflating: data/Blight/Corn_Blight (607).JPG
#   inflating: data/Blight/Corn_Blight (608).JPG
#   inflating: data/Blight/Corn_Blight (609).JPG
#   inflating: data/Blight/Corn_Blight (61).jpg
#   inflating: data/Blight/Corn_Blight (610).JPG
#   inflating: data/Blight/Corn_Blight (611).JPG
#   inflating: data/Blight/Corn_Blight (612).JPG
#   inflating: data/Blight/Corn_Blight (613).JPG
#   inflating: data/Blight/Corn_Blight (614).JPG
#   inflating: data/Blight/Corn_Blight (615).JPG
#   inflating: data/Blight/Corn_Blight (616).JPG
#   inflating: data/Blight/Corn_Blight (617).JPG
#   inflating: data/Blight/Corn_Blight (618).JPG
#   inflating: data/Blight/Corn_Blight (619).JPG
#   inflating: data/Blight/Corn_Blight (62).jpg
#   inflating: data/Blight/Corn_Blight (620).JPG
#   inflating: data/Blight/Corn_Blight (621).JPG
#   inflating: data/Blight/Corn_Blight (622).JPG
#   inflating: data/Blight/Corn_Blight (623).JPG
#   inflating: data/Blight/Corn_Blight (624).JPG
#   inflating: data/Blight/Corn_Blight (625).JPG
#   inflating: data/Blight/Corn_Blight (626).JPG
#   inflating: data/Blight/Corn_Blight (627).JPG
#   inflating: data/Blight/Corn_Blight (628).JPG
#   inflating: data/Blight/Corn_Blight (629).JPG
#   inflating: data/Blight/Corn_Blight (63).jpg
#   inflating: data/Blight/Corn_Blight (630).JPG
#   inflating: data/Blight/Corn_Blight (631).JPG
#   inflating: data/Blight/Corn_Blight (632).JPG
#   inflating: data/Blight/Corn_Blight (633).JPG
#   inflating: data/Blight/Corn_Blight (634).JPG
#   inflating: data/Blight/Corn_Blight (635).JPG
#   inflating: data/Blight/Corn_Blight (636).jpg
#   inflating: data/Blight/Corn_Blight (637).JPG
#   inflating: data/Blight/Corn_Blight (638).jpg
#   inflating: data/Blight/Corn_Blight (639).JPG
#   inflating: data/Blight/Corn_Blight (64).jpg
#   inflating: data/Blight/Corn_Blight (640).JPG
#   inflating: data/Blight/Corn_Blight (641).JPG
#   inflating: data/Blight/Corn_Blight (642).JPG
#   inflating: data/Blight/Corn_Blight (643).JPG
#   inflating: data/Blight/Corn_Blight (644).JPG
#   inflating: data/Blight/Corn_Blight (645).JPG
#   inflating: data/Blight/Corn_Blight (646).jpg
#   inflating: data/Blight/Corn_Blight (647).JPG
#   inflating: data/Blight/Corn_Blight (648).JPG
#   inflating: data/Blight/Corn_Blight (649).JPG
#   inflating: data/Blight/Corn_Blight (65).jpg
#   inflating: data/Blight/Corn_Blight (650).jpg
#   inflating: data/Blight/Corn_Blight (651).JPG
#   inflating: data/Blight/Corn_Blight (652).JPG
#   inflating: data/Blight/Corn_Blight (653).JPG
#   inflating: data/Blight/Corn_Blight (654).JPG
#   inflating: data/Blight/Corn_Blight (655).jpg
#   inflating: data/Blight/Corn_Blight (656).JPG
#   inflating: data/Blight/Corn_Blight (657).JPG
#   inflating: data/Blight/Corn_Blight (658).JPG
#   inflating: data/Blight/Corn_Blight (659).JPG
#   inflating: data/Blight/Corn_Blight (66).jpg
#   inflating: data/Blight/Corn_Blight (660).JPG
#   inflating: data/Blight/Corn_Blight (661).jpg
#   inflating: data/Blight/Corn_Blight (662).JPG
#   inflating: data/Blight/Corn_Blight (663).JPG
#   inflating: data/Blight/Corn_Blight (664).JPG
#   inflating: data/Blight/Corn_Blight (665).JPG
#   inflating: data/Blight/Corn_Blight (666).JPG
#   inflating: data/Blight/Corn_Blight (667).JPG
#   inflating: data/Blight/Corn_Blight (668).JPG
#   inflating: data/Blight/Corn_Blight (669).JPG
#   inflating: data/Blight/Corn_Blight (67).jpg
#   inflating: data/Blight/Corn_Blight (670).JPG
#   inflating: data/Blight/Corn_Blight (671).JPG
#   inflating: data/Blight/Corn_Blight (672).JPG
#   inflating: data/Blight/Corn_Blight (673).JPG
#   inflating: data/Blight/Corn_Blight (674).JPG
#   inflating: data/Blight/Corn_Blight (675).JPG
#   inflating: data/Blight/Corn_Blight (676).JPG
#   inflating: data/Blight/Corn_Blight (677).jpg
#   inflating: data/Blight/Corn_Blight (678).jpg
#   inflating: data/Blight/Corn_Blight (679).JPG
#   inflating: data/Blight/Corn_Blight (68).jpg
#   inflating: data/Blight/Corn_Blight (680).JPG
#   inflating: data/Blight/Corn_Blight (681).JPG
#   inflating: data/Blight/Corn_Blight (682).JPG
#   inflating: data/Blight/Corn_Blight (683).JPG
#   inflating: data/Blight/Corn_Blight (684).JPG
#   inflating: data/Blight/Corn_Blight (685).JPG
#   inflating: data/Blight/Corn_Blight (686).JPG
#   inflating: data/Blight/Corn_Blight (687).JPG
#   inflating: data/Blight/Corn_Blight (688).JPG
#   inflating: data/Blight/Corn_Blight (689).JPG
#   inflating: data/Blight/Corn_Blight (69).jpg
#   inflating: data/Blight/Corn_Blight (690).JPG
#   inflating: data/Blight/Corn_Blight (691).JPG
#   inflating: data/Blight/Corn_Blight (692).JPG
#   inflating: data/Blight/Corn_Blight (693).JPG
#   inflating: data/Blight/Corn_Blight (694).JPG
#   inflating: data/Blight/Corn_Blight (695).JPG
#   inflating: data/Blight/Corn_Blight (696).JPG
#   inflating: data/Blight/Corn_Blight (697).JPG
#   inflating: data/Blight/Corn_Blight (698).JPG
#   inflating: data/Blight/Corn_Blight (699).JPG
#   inflating: data/Blight/Corn_Blight (7).jpg
#   inflating: data/Blight/Corn_Blight (70).jpg
#   inflating: data/Blight/Corn_Blight (700).JPG
#   inflating: data/Blight/Corn_Blight (701).JPG
#   inflating: data/Blight/Corn_Blight (702).JPG
#   inflating: data/Blight/Corn_Blight (703).jpg
#   inflating: data/Blight/Corn_Blight (704).JPG
#   inflating: data/Blight/Corn_Blight (705).JPG
#   inflating: data/Blight/Corn_Blight (706).JPG
#   inflating: data/Blight/Corn_Blight (707).JPG
#   inflating: data/Blight/Corn_Blight (708).JPG
#   inflating: data/Blight/Corn_Blight (709).jpg
#   inflating: data/Blight/Corn_Blight (71).jpg
#   inflating: data/Blight/Corn_Blight (710).JPG
#   inflating: data/Blight/Corn_Blight (711).JPG
#   inflating: data/Blight/Corn_Blight (712).JPG
#   inflating: data/Blight/Corn_Blight (713).jpg
#   inflating: data/Blight/Corn_Blight (714).JPG
#   inflating: data/Blight/Corn_Blight (715).JPG
#   inflating: data/Blight/Corn_Blight (716).JPG
#   inflating: data/Blight/Corn_Blight (717).JPG
#   inflating: data/Blight/Corn_Blight (718).jpg
#   inflating: data/Blight/Corn_Blight (719).JPG
#   inflating: data/Blight/Corn_Blight (72).jpg
#   inflating: data/Blight/Corn_Blight (720).jpg
#   inflating: data/Blight/Corn_Blight (721).JPG
#   inflating: data/Blight/Corn_Blight (722).JPG
#   inflating: data/Blight/Corn_Blight (723).jpg
#   inflating: data/Blight/Corn_Blight (724).JPG
#   inflating: data/Blight/Corn_Blight (725).JPG
#   inflating: data/Blight/Corn_Blight (726).JPG
#   inflating: data/Blight/Corn_Blight (727).JPG
#   inflating: data/Blight/Corn_Blight (728).JPG
#   inflating: data/Blight/Corn_Blight (729).JPG
#   inflating: data/Blight/Corn_Blight (73).jpg
#   inflating: data/Blight/Corn_Blight (730).JPG
#   inflating: data/Blight/Corn_Blight (731).JPG
#   inflating: data/Blight/Corn_Blight (732).JPG
#   inflating: data/Blight/Corn_Blight (733).JPG
#   inflating: data/Blight/Corn_Blight (734).JPG
#   inflating: data/Blight/Corn_Blight (735).jpg
#   inflating: data/Blight/Corn_Blight (736).JPG
#   inflating: data/Blight/Corn_Blight (737).JPG
#   inflating: data/Blight/Corn_Blight (738).JPG
#   inflating: data/Blight/Corn_Blight (739).JPG
#   inflating: data/Blight/Corn_Blight (74).jpg
#   inflating: data/Blight/Corn_Blight (740).JPG
#   inflating: data/Blight/Corn_Blight (741).JPG
#   inflating: data/Blight/Corn_Blight (742).JPG
#   inflating: data/Blight/Corn_Blight (743).jpg
#   inflating: data/Blight/Corn_Blight (744).JPG
#   inflating: data/Blight/Corn_Blight (745).JPG
#   inflating: data/Blight/Corn_Blight (746).JPG
#   inflating: data/Blight/Corn_Blight (747).JPG
#   inflating: data/Blight/Corn_Blight (748).JPG
#   inflating: data/Blight/Corn_Blight (749).JPG
#   inflating: data/Blight/Corn_Blight (75).jpg
#   inflating: data/Blight/Corn_Blight (750).JPG
#   inflating: data/Blight/Corn_Blight (751).JPG
#   inflating: data/Blight/Corn_Blight (752).JPG
#   inflating: data/Blight/Corn_Blight (753).JPG
#   inflating: data/Blight/Corn_Blight (754).jpg
#   inflating: data/Blight/Corn_Blight (755).JPG
#   inflating: data/Blight/Corn_Blight (756).JPG
#   inflating: data/Blight/Corn_Blight (757).JPG
#   inflating: data/Blight/Corn_Blight (758).JPG
#   inflating: data/Blight/Corn_Blight (759).JPG
#   inflating: data/Blight/Corn_Blight (76).jpg
#   inflating: data/Blight/Corn_Blight (760).JPG
#   inflating: data/Blight/Corn_Blight (761).JPG
#   inflating: data/Blight/Corn_Blight (762).JPG
#   inflating: data/Blight/Corn_Blight (763).JPG
#   inflating: data/Blight/Corn_Blight (764).JPG
#   inflating: data/Blight/Corn_Blight (765).JPG
#   inflating: data/Blight/Corn_Blight (766).JPG
#   inflating: data/Blight/Corn_Blight (767).JPG
#   inflating: data/Blight/Corn_Blight (768).JPG
#   inflating: data/Blight/Corn_Blight (769).JPG
#   inflating: data/Blight/Corn_Blight (77).jpg
#   inflating: data/Blight/Corn_Blight (770).JPG
#   inflating: data/Blight/Corn_Blight (771).JPG
#   inflating: data/Blight/Corn_Blight (772).JPG
#   inflating: data/Blight/Corn_Blight (773).JPG
#   inflating: data/Blight/Corn_Blight (774).JPG
#   inflating: data/Blight/Corn_Blight (775).JPG
#   inflating: data/Blight/Corn_Blight (776).JPG
#   inflating: data/Blight/Corn_Blight (777).JPG
#   inflating: data/Blight/Corn_Blight (778).JPG
#   inflating: data/Blight/Corn_Blight (779).JPG
#   inflating: data/Blight/Corn_Blight (78).jpg
#   inflating: data/Blight/Corn_Blight (780).JPG
#   inflating: data/Blight/Corn_Blight (781).JPG
#   inflating: data/Blight/Corn_Blight (782).JPG
#   inflating: data/Blight/Corn_Blight (783).JPG
#   inflating: data/Blight/Corn_Blight (784).jpg
#   inflating: data/Blight/Corn_Blight (785).JPG
#   inflating: data/Blight/Corn_Blight (786).JPG
#   inflating: data/Blight/Corn_Blight (787).JPG
#   inflating: data/Blight/Corn_Blight (788).JPG
#   inflating: data/Blight/Corn_Blight (789).JPG
#   inflating: data/Blight/Corn_Blight (79).jpg
#   inflating: data/Blight/Corn_Blight (790).JPG
#   inflating: data/Blight/Corn_Blight (791).JPG
#   inflating: data/Blight/Corn_Blight (792).JPG
#   inflating: data/Blight/Corn_Blight (793).JPG
#   inflating: data/Blight/Corn_Blight (794).JPG
#   inflating: data/Blight/Corn_Blight (795).JPG
#   inflating: data/Blight/Corn_Blight (796).JPG
#   inflating: data/Blight/Corn_Blight (797).jpg
#   inflating: data/Blight/Corn_Blight (798).JPG
#   inflating: data/Blight/Corn_Blight (799).JPG
#   inflating: data/Blight/Corn_Blight (8).jpg
#   inflating: data/Blight/Corn_Blight (80).jpg
#   inflating: data/Blight/Corn_Blight (800).JPG
#   inflating: data/Blight/Corn_Blight (801).JPG
#   inflating: data/Blight/Corn_Blight (802).JPG
#   inflating: data/Blight/Corn_Blight (803).JPG
#   inflating: data/Blight/Corn_Blight (804).JPG
#   inflating: data/Blight/Corn_Blight (805).JPG
#   inflating: data/Blight/Corn_Blight (806).JPG
#   inflating: data/Blight/Corn_Blight (807).JPG
#   inflating: data/Blight/Corn_Blight (808).JPG
#   inflating: data/Blight/Corn_Blight (809).JPG
#   inflating: data/Blight/Corn_Blight (81).jpg
#   inflating: data/Blight/Corn_Blight (810).JPG
#   inflating: data/Blight/Corn_Blight (811).JPG
#   inflating: data/Blight/Corn_Blight (812).JPG
#   inflating: data/Blight/Corn_Blight (813).JPG
#   inflating: data/Blight/Corn_Blight (814).JPG
#   inflating: data/Blight/Corn_Blight (815).JPG
#   inflating: data/Blight/Corn_Blight (816).JPG
#   inflating: data/Blight/Corn_Blight (817).JPG
#   inflating: data/Blight/Corn_Blight (818).JPG
#   inflating: data/Blight/Corn_Blight (819).JPG
#   inflating: data/Blight/Corn_Blight (82).jpg
#   inflating: data/Blight/Corn_Blight (820).jpg
#   inflating: data/Blight/Corn_Blight (821).JPG
#   inflating: data/Blight/Corn_Blight (822).JPG
#   inflating: data/Blight/Corn_Blight (823).JPG
#   inflating: data/Blight/Corn_Blight (824).JPG
#   inflating: data/Blight/Corn_Blight (825).JPG
#   inflating: data/Blight/Corn_Blight (826).JPG
#   inflating: data/Blight/Corn_Blight (827).JPG
#   inflating: data/Blight/Corn_Blight (828).JPG
#   inflating: data/Blight/Corn_Blight (829).JPG
#   inflating: data/Blight/Corn_Blight (83).jpg
#   inflating: data/Blight/Corn_Blight (830).jpg
#   inflating: data/Blight/Corn_Blight (831).jpg
#   inflating: data/Blight/Corn_Blight (832).JPG
#   inflating: data/Blight/Corn_Blight (833).JPG
#   inflating: data/Blight/Corn_Blight (834).JPG
#   inflating: data/Blight/Corn_Blight (835).JPG
#   inflating: data/Blight/Corn_Blight (836).JPG
#   inflating: data/Blight/Corn_Blight (837).JPG
#   inflating: data/Blight/Corn_Blight (838).JPG
#   inflating: data/Blight/Corn_Blight (839).JPG
#   inflating: data/Blight/Corn_Blight (84).jpg
#   inflating: data/Blight/Corn_Blight (840).JPG
#   inflating: data/Blight/Corn_Blight (841).JPG
#   inflating: data/Blight/Corn_Blight (842).JPG
#   inflating: data/Blight/Corn_Blight (843).JPG
#   inflating: data/Blight/Corn_Blight (844).JPG
#   inflating: data/Blight/Corn_Blight (845).JPG
#   inflating: data/Blight/Corn_Blight (846).jpg
# ...
#   inflating: data/Healthy/Corn_Health (710).jpg
#   inflating: data/Healthy/Corn_Health (711).jpg
#   inflating: data/Healthy/Corn_Health (712).jpg
#   inflating: data/Healthy/Corn_Health (713).jpg
#   inflating: data/Healthy/Corn_Health (714).jpg
#   inflating: data/Healthy/Corn_Health (715).jpg
#   inflating: data/Healthy/Corn_Health (716).jpg
#   inflating: data/Healthy/Corn_Health (717).jpg
#   inflating: data/Healthy/Corn_Health (718).jpg
#   inflating: data/Healthy/Corn_Health (719).jpg
#   inflating: data/Healthy/Corn_Health (72).jpg
#   inflating: data/Healthy/Corn_Health (720).jpg
#   inflating: data/Healthy/Corn_Health (721).jpg
#   inflating: data/Healthy/Corn_Health (722).jpg
#   inflating: data/Healthy/Corn_Health (723).jpg
#   inflating: data/Healthy/Corn_Health (724).jpg
#   inflating: data/Healthy/Corn_Health (725).jpg
#   inflating: data/Healthy/Corn_Health (726).jpg
#   inflating: data/Healthy/Corn_Health (727).jpg
#   inflating: data/Healthy/Corn_Health (728).jpg
#   inflating: data/Healthy/Corn_Health (729).jpg
#   inflating: data/Healthy/Corn_Health (73).jpg
#   inflating: data/Healthy/Corn_Health (730).jpg
#   inflating: data/Healthy/Corn_Health (731).jpg
#   inflating: data/Healthy/Corn_Health (732).jpg
#   inflating: data/Healthy/Corn_Health (733).jpg
#   inflating: data/Healthy/Corn_Health (734).jpg
#   inflating: data/Healthy/Corn_Health (735).jpg
#   inflating: data/Healthy/Corn_Health (736).jpg
#   inflating: data/Healthy/Corn_Health (737).jpg
#   inflating: data/Healthy/Corn_Health (738).jpg
#   inflating: data/Healthy/Corn_Health (739).jpg
#   inflating: data/Healthy/Corn_Health (74).jpg
#   inflating: data/Healthy/Corn_Health (740).jpg
#   inflating: data/Healthy/Corn_Health (741).jpg
#   inflating: data/Healthy/Corn_Health (742).jpg
#   inflating: data/Healthy/Corn_Health (743).jpg
#   inflating: data/Healthy/Corn_Health (744).jpg
#   inflating: data/Healthy/Corn_Health (745).jpg
#   inflating: data/Healthy/Corn_Health (746).jpg
#   inflating: data/Healthy/Corn_Health (747).jpg
#   inflating: data/Healthy/Corn_Health (748).jpg
#   inflating: data/Healthy/Corn_Health (749).jpg
#   inflating: data/Healthy/Corn_Health (75).jpg
#   inflating: data/Healthy/Corn_Health (750).jpg
#   inflating: data/Healthy/Corn_Health (751).jpg
#   inflating: data/Healthy/Corn_Health (752).jpg
#   inflating: data/Healthy/Corn_Health (753).jpg
#   inflating: data/Healthy/Corn_Health (754).jpg
#   inflating: data/Healthy/Corn_Health (755).jpg
#   inflating: data/Healthy/Corn_Health (756).jpg
#   inflating: data/Healthy/Corn_Health (757).jpg
#   inflating: data/Healthy/Corn_Health (758).jpg
#   inflating: data/Healthy/Corn_Health (759).jpg
#   inflating: data/Healthy/Corn_Health (76).jpg
#   inflating: data/Healthy/Corn_Health (760).jpg
#   inflating: data/Healthy/Corn_Health (761).jpg
#   inflating: data/Healthy/Corn_Health (762).jpg
#   inflating: data/Healthy/Corn_Health (763).jpg
#   inflating: data/Healthy/Corn_Health (764).jpg
#   inflating: data/Healthy/Corn_Health (765).jpg
#   inflating: data/Healthy/Corn_Health (766).jpg
#   inflating: data/Healthy/Corn_Health (767).jpg
#   inflating: data/Healthy/Corn_Health (768).jpg
#   inflating: data/Healthy/Corn_Health (769).jpg
#   inflating: data/Healthy/Corn_Health (77).jpg
#   inflating: data/Healthy/Corn_Health (770).jpg
#   inflating: data/Healthy/Corn_Health (771).jpg
#   inflating: data/Healthy/Corn_Health (772).jpg
#   inflating: data/Healthy/Corn_Health (773).jpg
#   inflating: data/Healthy/Corn_Health (774).jpg
#   inflating: data/Healthy/Corn_Health (775).jpg
#   inflating: data/Healthy/Corn_Health (776).jpg
#   inflating: data/Healthy/Corn_Health (777).jpg
#   inflating: data/Healthy/Corn_Health (778).jpg
#   inflating: data/Healthy/Corn_Health (779).jpg
#   inflating: data/Healthy/Corn_Health (78).jpg
#   inflating: data/Healthy/Corn_Health (780).jpg
#   inflating: data/Healthy/Corn_Health (781).jpg
#   inflating: data/Healthy/Corn_Health (782).jpg
#   inflating: data/Healthy/Corn_Health (783).jpg
#   inflating: data/Healthy/Corn_Health (784).jpg
#   inflating: data/Healthy/Corn_Health (785).jpg
#   inflating: data/Healthy/Corn_Health (786).jpg
#   inflating: data/Healthy/Corn_Health (787).jpg
#   inflating: data/Healthy/Corn_Health (788).jpg
#   inflating: data/Healthy/Corn_Health (789).jpg
#   inflating: data/Healthy/Corn_Health (79).jpg
#   inflating: data/Healthy/Corn_Health (790).jpg
#   inflating: data/Healthy/Corn_Health (791).jpg
#   inflating: data/Healthy/Corn_Health (792).jpg
#   inflating: data/Healthy/Corn_Health (793).jpg
#   inflating: data/Healthy/Corn_Health (794).jpg
#   inflating: data/Healthy/Corn_Health (795).jpg
#   inflating: data/Healthy/Corn_Health (796).jpg
#   inflating: data/Healthy/Corn_Health (797).jpg
#   inflating: data/Healthy/Corn_Health (798).jpg
#   inflating: data/Healthy/Corn_Health (799).jpg
#   inflating: data/Healthy/Corn_Health (8).jpg
#   inflating: data/Healthy/Corn_Health (80).jpg
#   inflating: data/Healthy/Corn_Health (800).jpg
#   inflating: data/Healthy/Corn_Health (801).jpg
#   inflating: data/Healthy/Corn_Health (802).jpg
#   inflating: data/Healthy/Corn_Health (803).jpg
#   inflating: data/Healthy/Corn_Health (804).jpg
#   inflating: data/Healthy/Corn_Health (805).jpg
#   inflating: data/Healthy/Corn_Health (806).jpg
#   inflating: data/Healthy/Corn_Health (807).jpg
#   inflating: data/Healthy/Corn_Health (808).jpg
#   inflating: data/Healthy/Corn_Health (809).jpg
#   inflating: data/Healthy/Corn_Health (81).jpg
#   inflating: data/Healthy/Corn_Health (810).jpg
#   inflating: data/Healthy/Corn_Health (811).jpg
#   inflating: data/Healthy/Corn_Health (812).jpg
#   inflating: data/Healthy/Corn_Health (813).jpg
#   inflating: data/Healthy/Corn_Health (814).jpg
#   inflating: data/Healthy/Corn_Health (815).jpg
#   inflating: data/Healthy/Corn_Health (816).jpg
#   inflating: data/Healthy/Corn_Health (817).jpg
#   inflating: data/Healthy/Corn_Health (818).jpg
#   inflating: data/Healthy/Corn_Health (819).jpg
#   inflating: data/Healthy/Corn_Health (82).jpg
#   inflating: data/Healthy/Corn_Health (820).jpg
#   inflating: data/Healthy/Corn_Health (821).jpg
#   inflating: data/Healthy/Corn_Health (822).jpg
#   inflating: data/Healthy/Corn_Health (823).jpg
#   inflating: data/Healthy/Corn_Health (824).jpg
#   inflating: data/Healthy/Corn_Health (825).jpg
#   inflating: data/Healthy/Corn_Health (826).jpg
#   inflating: data/Healthy/Corn_Health (827).jpg
#   inflating: data/Healthy/Corn_Health (828).jpg
#   inflating: data/Healthy/Corn_Health (829).jpg
#   inflating: data/Healthy/Corn_Health (83).jpg
#   inflating: data/Healthy/Corn_Health (830).jpg
#   inflating: data/Healthy/Corn_Health (831).jpg
#   inflating: data/Healthy/Corn_Health (832).jpg
#   inflating: data/Healthy/Corn_Health (833).jpg
#   inflating: data/Healthy/Corn_Health (834).jpg
#   inflating: data/Healthy/Corn_Health (835).jpg
#   inflating: data/Healthy/Corn_Health (836).jpg
#   inflating: data/Healthy/Corn_Health (837).jpg
#   inflating: data/Healthy/Corn_Health (838).jpg
#   inflating: data/Healthy/Corn_Health (839).jpg
#   inflating: data/Healthy/Corn_Health (84).jpg
#   inflating: data/Healthy/Corn_Health (840).jpg
#   inflating: data/Healthy/Corn_Health (841).jpg
#   inflating: data/Healthy/Corn_Health (842).jpg
#   inflating: data/Healthy/Corn_Health (843).jpg
#   inflating: data/Healthy/Corn_Health (844).jpg
#   inflating: data/Healthy/Corn_Health (845).JPG
#   inflating: data/Healthy/Corn_Health (846).jpg
#   inflating: data/Healthy/Corn_Health (847).jpg
#   inflating: data/Healthy/Corn_Health (848).jpg
#   inflating: data/Healthy/Corn_Health (849).jpg
#   inflating: data/Healthy/Corn_Health (85).jpg
#   inflating: data/Healthy/Corn_Health (850).jpg
#   inflating: data/Healthy/Corn_Health (851).jpg
#   inflating: data/Healthy/Corn_Health (852).jpg
#   inflating: data/Healthy/Corn_Health (853).jpg
#   inflating: data/Healthy/Corn_Health (854).jpg
#   inflating: data/Healthy/Corn_Health (855).jpg
#   inflating: data/Healthy/Corn_Health (856).jpg
#   inflating: data/Healthy/Corn_Health (857).jpg
#   inflating: data/Healthy/Corn_Health (858).jpg
#   inflating: data/Healthy/Corn_Health (859).jpg
#   inflating: data/Healthy/Corn_Health (86).jpg
#   inflating: data/Healthy/Corn_Health (860).jpg
#   inflating: data/Healthy/Corn_Health (861).jpg
#   inflating: data/Healthy/Corn_Health (862).jpg
#   inflating: data/Healthy/Corn_Health (863).jpg
#   inflating: data/Healthy/Corn_Health (864).jpg
#   inflating: data/Healthy/Corn_Health (865).jpg
#   inflating: data/Healthy/Corn_Health (866).jpg
#   inflating: data/Healthy/Corn_Health (867).jpg
#   inflating: data/Healthy/Corn_Health (868).jpg
#   inflating: data/Healthy/Corn_Health (869).jpg
#   inflating: data/Healthy/Corn_Health (87).jpg
#   inflating: data/Healthy/Corn_Health (870).jpg
#   inflating: data/Healthy/Corn_Health (871).jpg
#   inflating: data/Healthy/Corn_Health (872).jpg
#   inflating: data/Healthy/Corn_Health (873).jpg
#   inflating: data/Healthy/Corn_Health (874).jpg
#   inflating: data/Healthy/Corn_Health (875).jpg
#   inflating: data/Healthy/Corn_Health (876).jpg
#   inflating: data/Healthy/Corn_Health (877).jpg
#   inflating: data/Healthy/Corn_Health (878).jpg
#   inflating: data/Healthy/Corn_Health (879).jpg
#   inflating: data/Healthy/Corn_Health (88).jpg
#   inflating: data/Healthy/Corn_Health (880).jpg
#   inflating: data/Healthy/Corn_Health (881).jpg
#   inflating: data/Healthy/Corn_Health (882).jpg
#   inflating: data/Healthy/Corn_Health (883).jpg
#   inflating: data/Healthy/Corn_Health (884).jpg
#   inflating: data/Healthy/Corn_Health (885).jpg
#   inflating: data/Healthy/Corn_Health (886).jpg
#   inflating: data/Healthy/Corn_Health (887).JPG
#   inflating: data/Healthy/Corn_Health (888).jpg
#   inflating: data/Healthy/Corn_Health (889).jpg
#   inflating: data/Healthy/Corn_Health (89).jpg
#   inflating: data/Healthy/Corn_Health (890).jpg
#   inflating: data/Healthy/Corn_Health (891).jpg
#   inflating: data/Healthy/Corn_Health (892).jpg
#   inflating: data/Healthy/Corn_Health (893).jpg
#   inflating: data/Healthy/Corn_Health (894).jpg
#   inflating: data/Healthy/Corn_Health (895).jpg
#   inflating: data/Healthy/Corn_Health (896).jpg
#   inflating: data/Healthy/Corn_Health (897).jpg
#   inflating: data/Healthy/Corn_Health (898).jpg
#   inflating: data/Healthy/Corn_Health (899).jpg
#   inflating: data/Healthy/Corn_Health (9).jpg
#   inflating: data/Healthy/Corn_Health (90).jpg
#   inflating: data/Healthy/Corn_Health (900).jpg
#   inflating: data/Healthy/Corn_Health (901).jpg
#   inflating: data/Healthy/Corn_Health (902).jpg
#   inflating: data/Healthy/Corn_Health (903).jpg
#   inflating: data/Healthy/Corn_Health (904).jpg
#   inflating: data/Healthy/Corn_Health (905).jpg
#   inflating: data/Healthy/Corn_Health (906).jpg
#   inflating: data/Healthy/Corn_Health (907).jpg
#   inflating: data/Healthy/Corn_Health (908).jpg
#   inflating: data/Healthy/Corn_Health (909).jpg
#   inflating: data/Healthy/Corn_Health (91).jpg
#   inflating: data/Healthy/Corn_Health (910).jpg
#   inflating: data/Healthy/Corn_Health (911).jpg
#   inflating: data/Healthy/Corn_Health (912).jpg
#   inflating: data/Healthy/Corn_Health (913).jpg
#   inflating: data/Healthy/Corn_Health (914).jpg
#   inflating: data/Healthy/Corn_Health (915).jpg
#   inflating: data/Healthy/Corn_Health (916).jpg
#   inflating: data/Healthy/Corn_Health (917).jpg
#   inflating: data/Healthy/Corn_Health (918).jpg
#   inflating: data/Healthy/Corn_Health (919).jpg
#   inflating: data/Healthy/Corn_Health (92).jpg
#   inflating: data/Healthy/Corn_Health (920).jpg
#   inflating: data/Healthy/Corn_Health (921).jpg
#   inflating: data/Healthy/Corn_Health (922).jpg
#   inflating: data/Healthy/Corn_Health (923).jpg
#   inflating: data/Healthy/Corn_Health (924).jpg
#   inflating: data/Healthy/Corn_Health (925).jpg
#   inflating: data/Healthy/Corn_Health (926).jpg
#   inflating: data/Healthy/Corn_Health (927).jpg
#   inflating: data/Healthy/Corn_Health (928).jpg
#   inflating: data/Healthy/Corn_Health (929).jpg
#   inflating: data/Healthy/Corn_Health (93).jpg
#   inflating: data/Healthy/Corn_Health (930).jpg
#   inflating: data/Healthy/Corn_Health (931).jpg
#   inflating: data/Healthy/Corn_Health (932).jpg
#   inflating: data/Healthy/Corn_Health (933).jpg
#   inflating: data/Healthy/Corn_Health (934).jpg
#   inflating: data/Healthy/Corn_Health (935).jpg
#   inflating: data/Healthy/Corn_Health (936).jpg
#   inflating: data/Healthy/Corn_Health (937).jpg
#   inflating: data/Healthy/Corn_Health (938).jpg
#   inflating: data/Healthy/Corn_Health (939).jpg
#   inflating: data/Healthy/Corn_Health (94).jpg
#   inflating: data/Healthy/Corn_Health (940).jpg
#   inflating: data/Healthy/Corn_Health (941).jpg
#   inflating: data/Healthy/Corn_Health (942).jpg
#   inflating: data/Healthy/Corn_Health (943).jpg
#   inflating: data/Healthy/Corn_Health (944).jpg
#   inflating: data/Healthy/Corn_Health (945).jpg
#   inflating: data/Healthy/Corn_Health (946).jpg
#   inflating: data/Healthy/Corn_Health (947).jpg
#   inflating: data/Healthy/Corn_Health (948).jpg
#   inflating: data/Healthy/Corn_Health (949).jpg
#   inflating: data/Healthy/Corn_Health (95).jpg
#   inflating: data/Healthy/Corn_Health (950).jpg
#   inflating: data/Healthy/Corn_Health (951).jpg
#   inflating: data/Healthy/Corn_Health (952).jpg
#   inflating: data/Healthy/Corn_Health (953).jpg
#   inflating: data/Healthy/Corn_Health (954).jpg
#   inflating: data/Healthy/Corn_Health (955).jpg
#   inflating: data/Healthy/Corn_Health (956).jpg
#   inflating: data/Healthy/Corn_Health (957).jpg
#   inflating: data/Healthy/Corn_Health (958).jpg
#   inflating: data/Healthy/Corn_Health (959).jpg
#   inflating: data/Healthy/Corn_Health (96).jpg
#   inflating: data/Healthy/Corn_Health (960).jpg
#   inflating: data/Healthy/Corn_Health (961).jpg
#   inflating: data/Healthy/Corn_Health (962).jpg
#   inflating: data/Healthy/Corn_Health (963).jpg
#   inflating: data/Healthy/Corn_Health (964).jpg
#   inflating: data/Healthy/Corn_Health (965).jpg
#   inflating: data/Healthy/Corn_Health (966).jpg
#   inflating: data/Healthy/Corn_Health (967).jpg
#   inflating: data/Healthy/Corn_Health (968).jpg
#   inflating: data/Healthy/Corn_Health (969).jpg
#   inflating: data/Healthy/Corn_Health (97).jpg
#   inflating: data/Healthy/Corn_Health (970).jpg
#   inflating: data/Healthy/Corn_Health (971).jpg
#   inflating: data/Healthy/Corn_Health (972).jpg
#   inflating: data/Healthy/Corn_Health (973).jpg
#   inflating: data/Healthy/Corn_Health (974).jpg
#   inflating: data/Healthy/Corn_Health (975).jpg
#   inflating: data/Healthy/Corn_Health (976).jpg
#   inflating: data/Healthy/Corn_Health (977).jpg
#   inflating: data/Healthy/Corn_Health (978).jpg
#   inflating: data/Healthy/Corn_Health (979).jpg
#   inflating: data/Healthy/Corn_Health (98).jpg
#   inflating: data/Healthy/Corn_Health (980).jpg
#   inflating: data/Healthy/Corn_Health (981).jpg
#   inflating: data/Healthy/Corn_Health (982).JPG
#   inflating: data/Healthy/Corn_Health (983).jpg
#   inflating: data/Healthy/Corn_Health (984).jpg
#   inflating: data/Healthy/Corn_Health (985).jpg
#   inflating: data/Healthy/Corn_Health (986).jpg
#   inflating: data/Healthy/Corn_Health (987).jpg
#   inflating: data/Healthy/Corn_Health (988).jpg
#   inflating: data/Healthy/Corn_Health (989).jpg
#   inflating: data/Healthy/Corn_Health (99).jpg
#   inflating: data/Healthy/Corn_Health (990).jpg
#   inflating: data/Healthy/Corn_Health (991).jpg
#   inflating: data/Healthy/Corn_Health (992).jpg
#   inflating: data/Healthy/Corn_Health (993).jpg
#   inflating: data/Healthy/Corn_Health (994).jpg
#   inflating: data/Healthy/Corn_Health (995).jpg
#   inflating: data/Healthy/Corn_Health (996).jpg
#   inflating: data/Healthy/Corn_Health (997).jpg
#   inflating: data/Healthy/Corn_Health (998).jpg
#   inflating: data/Healthy/Corn_Health (999).jpg

# %% [markdown]
# ## <center>Corn Leaf Disease Detection</center>

# %% [markdown]
# <center><img src="https://images.unsplash.com/photo-1503788125311-ae8d4da8ab54?ixlib=rb-4.0.3&ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&auto=format&fit=crop&w=774&q=80"></center>

# %% [markdown]
# ## Importing Dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random

import torch
from torch.utils.data import DataLoader
from torchvision import transforms, datasets
from torch import nn
from torch.optim import Adam
from torchvision import models

from sklearn.metrics import classification_report, confusion_matrix

# %%
# !pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.5.1-py3-none-any.whl (8.4 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.5.1

# %%
import splitfolders

# %% [markdown]
# ## Choosing the Device

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ## Splitting the Data Into Train, Validation and Test Sets

# %% [markdown]
# Because the data is not seperated, it should be splitted into Train, Validation and Test sets. To do that, I used splitfolders library and splitted the data into Train, Validation and Test sets by 70%, 20% and 10% respectively.

# %%
splitfolders.ratio("/content/data",
            output="splitted_data",
            seed=42,
            ratio=(.7, .2, .1),
            group_prefix=None,
            move=False)
# Out:
# Copying files: 4188 files [00:01, 2189.05 files/s]

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# Resizing and Normalizing methods are applied to all of the datasets but data augmentation techniques are only applied to Train set in order to richen the data so that the model possibly will yield more accurate results.

# %%
#----------------------
train_transform = transforms.Compose([
    transforms.Resize(size=(256, 256)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomVerticalFlip(),
    transforms.GaussianBlur(kernel_size=(3, 7), sigma=(0.1, 2)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize(size=(256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize(size=(256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406],
                        std=[0.229, 0.224, 0.225])
])

# -------- Transformation for the Whole Dataset for Visualization Purposes --------
data_transform = transforms.Compose([
    transforms.Resize(size=(256, 256)),
    transforms.ToTensor(),
])

# %% [markdown]
# ## Loading the Data

# %%
train = datasets.ImageFolder(root="splitted_data/train",
                              transform=train_transform)

val = datasets.ImageFolder(root="splitted_data/val",
                              transform=val_transform)

test = datasets.ImageFolder(root="splitted_data/test",
                              transform=test_transform)

# -------- Getting the Whole Dataset for Visualization Purposes --------
data = datasets.ImageFolder(root="data",
                              transform=data_transform)

# %%
print("Dataset Labels:\n", train.class_to_idx, "\n")

for name, dataset in zip(["TRAIN", "VALIDATION", "TEST"], [train, val, test]):
    images_per_class = pd.Series(dataset.targets).value_counts()
    print(f"Images per Class in {name}:")
    print(images_per_class, "\n")
# Out:
# Dataset Labels:
#  {'Blight': 0, 'Common_Rust': 1, 'Gray_Leaf_Spot': 2, 'Healthy': 3}
#
# Images per Class in TRAIN:
# 1    914
# 3    813
# 0    802
# 2    401
# dtype: int64
#
# Images per Class in VALIDATION:
# 1    261
# 3    232
# 0    229
# 2    114
# dtype: int64
#
# Images per Class in TEST:
# 1    131
# 3    117
# 0    115
# 2     59
# dtype: int64

# %% [markdown]
# #### Plotting a few Images

# %% [markdown]
# Images plotted below did not undergo a data augmentation process. Therefore, they seem to be normal.

# %%
labels_for_viz = {v: k for k, v in data.class_to_idx.items()}

fig, ax = plt.subplots(3, 5, figsize=(15, 10))
ax = ax.flatten()
for i in range(15):
    sample = random.randint(0, len(data))
    ax[i].imshow(data[sample][0].permute(1, 2, 0))
    ax[i].title.set_text(labels_for_viz[data[sample][1]])

# %% [markdown]
# ### Plotting the Augmented Images

# %% [markdown]
# Because data augmentation methods are applied to Train set, it can be seen that images are blurred, horizontally and vertically flipped compared to the unaugmented images.

# %%
fig, ax = plt.subplots(3, 5, figsize=(15, 10))
ax = ax.flatten()
for i in range(15):
    sample = random.randint(0, len(train))
    ax[i].imshow(train[sample][0].permute(1, 2, 0))
    ax[i].title.set_text(labels_for_viz[train[sample][1]])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# Before passing the data in a neural network, it should be batched and shuffled. Since test will not be used in training process, there is no need to shuffle it.

# %%
train_dataloader = DataLoader(dataset=train,
                             batch_size=32,
                             num_workers=2,
                             shuffle=True)

val_dataloader = DataLoader(dataset=val,
                             batch_size=32,
                             num_workers=2,
                             shuffle=True)

test_dataloader = DataLoader(dataset=test,
                             batch_size=32,
                             num_workers=2,
                             shuffle=False)

# %% [markdown]
# When looking at the order of the data in relevant folder, it can be observed that images from class "Blight" comes first, "Common_Rust" second, "Gray_Leaf_Spot" third and "Healthy" last. An order as such can be problematic for the model to train unbiasedly. Let's take a batch and look at the labels to make sure that the data is shuffled.

# %%
img, label = next(iter(train_dataloader))
print("Batch and Image Shape:", img.shape, "--> [batch_size, color_channels, height, width]")
print("\nLabels:", label)
# Out:
# Batch and Image Shape: torch.Size([32, 3, 256, 256]) --> [batch_size, color_channels, height, width]
#
# Labels: tensor([0, 0, 3, 3, 2, 2, 0, 1, 1, 2, 0, 2, 0, 1, 0, 1, 0, 0, 3, 3, 3, 1, 3, 3,
#         2, 0, 1, 1, 1, 3, 3, 3])

# %% [markdown]
# ## Building the Deep Learning Model

# %% [markdown]
# Custom neural network architecture can be designed for this machine learning problem. With a neural network similar to the one below, an accuracy score around 80-84% is obtained. But for this project, I opt to apply Transfer Learning using ResNet18 architecture.

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.conv2 = nn.Sequential(
            nn.Conv2d(in_channels=32, out_channels=32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(in_features=131072, out_features=32), # in_features are selected based on the output that Flatten layer yields
            nn.ReLU(),
            nn.Linear(in_features=32, out_features=16),
            nn.ReLU(),
            nn.Linear(in_features=16, out_features=4)
        )

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.fc(x)
        return x

# %% [markdown]
# ## Transfer Learning - ResNet18

# %% [markdown]
# Transfer learning is a process of utilizing pre-trained machine learning models and applying them to a related task without need of models' learning from scratch for saving time and possibly better performance.

# %%
model = models.mobilenet_v2(pretrained=True)
model.fc = nn.Linear(in_features=512, out_features=4)
model = model.to(device)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=MobileNet_V2_Weights.IMAGENET1K_V1`. You can also use `weights=MobileNet_V2_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
# 100%|██████████| 13.6M/13.6M [00:00<00:00, 33.9MB/s]

# %%
print(model)
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): Conv2dNormActivation(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#           (1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(144, 144, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=144, bias=False)
#           (1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(144, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=192, bias=False)
#           (1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (8): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (9): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (10): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (11): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(64, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=384, bias=False)
#           (1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(384, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (12): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (13): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (14): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(96, 576, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(576, 576, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=576, bias=False)
#           (1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(576, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (15): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (16): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (17): InvertedResidual(
#       (conv): Sequential(
#         (0): Conv2dNormActivation(
#           (0): Conv2d(160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2dNormActivation(
#           (0): Conv2d(960, 960, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=960, bias=False)
#           (1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (2): Conv2d(960, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(320, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (18): Conv2dNormActivation(
#       (0): Conv2d(320, 1280, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (1): BatchNorm2d(1280, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Linear(in_features=1280, out_features=1000, bias=True)
#   )
#   (fc): Linear(in_features=512, out_features=4, bias=True)
# )

# %% [markdown]
# ## Defining the Loss Function and Choosing an Optimizer

# %%
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=10e-3)

# %% [markdown]
# ## Defining Train and Test Functions

# %%
def train_and_validate_model(num_epochs):
    val_best_accuracy = 0.0
    train_loss_history = []
    val_loss_history = []
    train_accuracy_history = []
    val_accuracy_history = []

    print("Training begins...")
    for epoch in range(1, num_epochs+1):
        running_train_loss = 0.0
        running_train_accuracy = 0.0
        train_total = 0
        running_val_accuracy = 0.0
        running_val_loss = 0.0
        val_total = 0


        # TRAINING LOOP
        for data in train_dataloader:
            inputs, outputs = data
            inputs, outputs = inputs.to(device), outputs.to(device)
            optimizer.zero_grad()
            predictions = model(inputs)
            train_loss = loss_fn(predictions, outputs)
            _, train_predicted = torch.max(predictions, 1)
            running_train_accuracy += (train_predicted == outputs).sum().item()
            train_total += outputs.size(0)
            train_loss.backward()
            optimizer.step()
            running_train_loss += train_loss.item()

        train_loss_value = running_train_loss/len(train_dataloader)
        train_loss_history.append(train_loss_value)
        train_accuracy = (100*running_train_accuracy)/train_total
        train_accuracy_history.append(train_accuracy)

        # VALIDATION LOOP
        with torch.no_grad():
            model.eval()
            for data in val_dataloader:
                inputs, outputs = data
                inputs, outputs = inputs.to(device), outputs.to(device)
                predictions = model(inputs)
                val_loss = loss_fn(predictions, outputs)

                _, val_predicted = torch.max(predictions, 1)
                running_val_loss += val_loss.item()
                val_total += outputs.size(0)
                running_val_accuracy += (val_predicted == outputs).sum().item()

        val_loss_value = running_val_loss/len(val_dataloader)
        val_loss_history.append(val_loss_value)
        val_accuracy = (100*running_val_accuracy)/val_total
        val_accuracy_history.append(val_accuracy)

        if val_accuracy > val_best_accuracy:
            torch.save(model.state_dict(), "model.pth")
            val_best_accuracy = val_accuracy

        print("Completed Epoch: ", epoch, "- Training Accuracy: %d" %train_accuracy, "- Validation Accuracy: %d" %val_accuracy, "- Training Loss: %.4f" %train_loss_value, "- Validation Loss: %.4f" %val_loss_value)
    return train_accuracy_history, val_accuracy_history, train_loss_history, val_loss_history

# %%
def test_model():
    model = models.mobilenet_v2(pretrained=True)
    model.fc = nn.Linear(in_features=512, out_features=4)
    model = model.to(device)
    path = "model.pth"
    model.load_state_dict(torch.load(path))
    model.eval()

    running_accuracy = 0
    total = 0
    all_predictions = []

    with torch.no_grad():
        for data in test_dataloader:
            inputs, outputs = data
            inputs, outputs = inputs.to(device), outputs.to(device)
            outputs = outputs.to(torch.float32)
            predictions = model(inputs)
            _, predicted = torch.max(predictions, 1)
            total += outputs.size(0)
            running_accuracy += (predicted == outputs).sum().item()
            accuracy = 100*running_accuracy/total

            all_predictions.append(list(predicted.to("cpu").numpy()))
        print("Test Accuracy: ", accuracy)
    return np.hstack(all_predictions) # returns a flattened array of batches of predictions

# %%
EPOCHS = 50
train_accuracy_history, val_accuracy_history, train_loss_history, val_loss_history = train_and_validate_model(EPOCHS)
print("Training finished...\n")
# Out:
# Training begins...
# Completed Epoch:  1 - Training Accuracy: 86 - Validation Accuracy: 93 - Training Loss: 0.6698 - Validation Loss: 0.2407
# Completed Epoch:  2 - Training Accuracy: 25 - Validation Accuracy: 27 - Training Loss: 17.7639 - Validation Loss: 24.4967
# Completed Epoch:  3 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.9284 - Validation Loss: 12.4303
# Completed Epoch:  4 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.9142 - Validation Loss: 23.6314
# Completed Epoch:  5 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 18.3445 - Validation Loss: 28.0002
# Completed Epoch:  6 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.4212 - Validation Loss: 22.3703
# Completed Epoch:  7 - Training Accuracy: 26 - Validation Accuracy: 31 - Training Loss: 18.0375 - Validation Loss: 29.2514
# Completed Epoch:  8 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.1152 - Validation Loss: 25.4097
# Completed Epoch:  9 - Training Accuracy: 27 - Validation Accuracy: 27 - Training Loss: 16.6965 - Validation Loss: 17.3021
# Completed Epoch:  10 - Training Accuracy: 26 - Validation Accuracy: 31 - Training Loss: 18.0652 - Validation Loss: 9.8750
# Completed Epoch:  11 - Training Accuracy: 26 - Validation Accuracy: 31 - Training Loss: 17.7577 - Validation Loss: 29.1341
# Completed Epoch:  12 - Training Accuracy: 25 - Validation Accuracy: 31 - Training Loss: 18.4801 - Validation Loss: 17.5325
# Completed Epoch:  13 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.6287 - Validation Loss: 22.2784
# Completed Epoch:  14 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.9256 - Validation Loss: 32.1111
# Completed Epoch:  15 - Training Accuracy: 25 - Validation Accuracy: 27 - Training Loss: 18.1645 - Validation Loss: 10.6051
# Completed Epoch:  16 - Training Accuracy: 26 - Validation Accuracy: 31 - Training Loss: 17.2796 - Validation Loss: 14.3586
# Completed Epoch:  17 - Training Accuracy: 25 - Validation Accuracy: 13 - Training Loss: 17.1358 - Validation Loss: 6.4198
# Completed Epoch:  18 - Training Accuracy: 28 - Validation Accuracy: 27 - Training Loss: 16.5482 - Validation Loss: 17.4819
# Completed Epoch:  19 - Training Accuracy: 28 - Validation Accuracy: 13 - Training Loss: 16.3552 - Validation Loss: 15.0069
# Completed Epoch:  20 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.6457 - Validation Loss: 24.0892
# Completed Epoch:  21 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.9747 - Validation Loss: 15.2175
# Completed Epoch:  22 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 18.2167 - Validation Loss: 16.1804
# Completed Epoch:  23 - Training Accuracy: 27 - Validation Accuracy: 27 - Training Loss: 17.6688 - Validation Loss: 8.1598
# Completed Epoch:  24 - Training Accuracy: 26 - Validation Accuracy: 31 - Training Loss: 17.7489 - Validation Loss: 21.2067
# Completed Epoch:  25 - Training Accuracy: 25 - Validation Accuracy: 31 - Training Loss: 17.7963 - Validation Loss: 8.0064
# Completed Epoch:  26 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.7747 - Validation Loss: 16.0132
# Completed Epoch:  27 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.6361 - Validation Loss: 21.6078
# Completed Epoch:  28 - Training Accuracy: 26 - Validation Accuracy: 31 - Training Loss: 17.6651 - Validation Loss: 22.1926
# Completed Epoch:  29 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.8620 - Validation Loss: 15.9341
# Completed Epoch:  30 - Training Accuracy: 25 - Validation Accuracy: 31 - Training Loss: 17.5332 - Validation Loss: 10.2562
# Completed Epoch:  31 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.8920 - Validation Loss: 18.9030
# Completed Epoch:  32 - Training Accuracy: 25 - Validation Accuracy: 27 - Training Loss: 18.5956 - Validation Loss: 12.8160
# Completed Epoch:  33 - Training Accuracy: 27 - Validation Accuracy: 27 - Training Loss: 17.2815 - Validation Loss: 31.9241
# Completed Epoch:  34 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 18.0160 - Validation Loss: 14.6324
# Completed Epoch:  35 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.6897 - Validation Loss: 14.2531
# Completed Epoch:  36 - Training Accuracy: 26 - Validation Accuracy: 31 - Training Loss: 18.0503 - Validation Loss: 24.8228
# Completed Epoch:  37 - Training Accuracy: 25 - Validation Accuracy: 27 - Training Loss: 18.7924 - Validation Loss: 18.8008
# Completed Epoch:  38 - Training Accuracy: 26 - Validation Accuracy: 31 - Training Loss: 17.7039 - Validation Loss: 29.5379
# Completed Epoch:  39 - Training Accuracy: 28 - Validation Accuracy: 27 - Training Loss: 17.4466 - Validation Loss: 24.6937
# Completed Epoch:  40 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.7645 - Validation Loss: 18.6181
# Completed Epoch:  41 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.3441 - Validation Loss: 27.2985
# Completed Epoch:  42 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 18.0403 - Validation Loss: 26.9899
# Completed Epoch:  43 - Training Accuracy: 27 - Validation Accuracy: 13 - Training Loss: 17.1206 - Validation Loss: 25.8568
# Completed Epoch:  44 - Training Accuracy: 25 - Validation Accuracy: 27 - Training Loss: 17.8236 - Validation Loss: 34.6642
# Completed Epoch:  45 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.9403 - Validation Loss: 29.7915
# Completed Epoch:  46 - Training Accuracy: 26 - Validation Accuracy: 27 - Training Loss: 17.2203 - Validation Loss: 12.2111
# Completed Epoch:  47 - Training Accuracy: 25 - Validation Accuracy: 31 - Training Loss: 18.0626 - Validation Loss: 23.6059
# Completed Epoch:  48 - Training Accuracy: 27 - Validation Accuracy: 27 - Training Loss: 16.5197 - Validation Loss: 38.9390
# Completed Epoch:  49 - Training Accuracy: 25 - Validation Accuracy: 27 - Training Loss: 18.2069 - Validation Loss: 28.6949
# Completed Epoch:  50 - Training Accuracy: 25 - Validation Accuracy: 27 - Training Loss: 18.2994 - Validation Loss: 35.3606
# Training finished...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-16cd5ca51457> in <cell line: 4>()
#       2 train_accuracy_history, val_accuracy_history, train_loss_history, val_loss_history = train_and_validate_model(EPOCHS)
#       3 print("Training finished...\n")
# ----> 4 all_preds = test_model()
#
# <ipython-input-27-014958636bdf> in test_model()
#       1 def test_model():
# ----> 2     model = models.mobilenet(pretrained=True)
#       3     model.fc = nn.Linear(in_features=512, out_features=4)
#       4     model = model.to(device)
#       5     path = "model.pth"
#
# TypeError: 'module' object is not callable

# %%
all_preds = test_model()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-6ab3bfa5c8c1> in <cell line: 1>()
# ----> 1 all_preds = test_model()
#
# <ipython-input-27-014958636bdf> in test_model()
#       1 def test_model():
# ----> 2     model = models.mobilenet(pretrained=True)
#       3     model.fc = nn.Linear(in_features=512, out_features=4)
#       4     model = model.to(device)
#       5     path = "model.pth"
#
# TypeError: 'module' object is not callable

# %%
fig, ax = plt.subplots(2, 1, figsize=(12, 10))
ax = ax.flatten()

ax[0].plot(train_loss_history, label="Train")
ax[0].plot(val_loss_history, label="Validation")
ax[0].title.set_text("Loss")
ax[0].legend()

ax[1].plot(train_accuracy_history, label="Train")
ax[1].plot(val_accuracy_history, label="Validation")
ax[1].title.set_text("Accuracy Score")
ax[1].legend()

plt.show()

# %%
print(classification_report(test.targets, all_preds))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-e8ac72356431> in <cell line: 1>()
# ----> 1 print(classification_report(test.targets, all_preds))
#
# NameError: name 'all_preds' is not defined

# %%
plt.figure(figsize=(10, 7))
sns.heatmap(confusion_matrix(test.targets, all_preds), cmap="Blues", annot=True, fmt="d")
plt.title("Confusion Matrix", size=15)
plt.show()

# %% [markdown]
# ## Manual Testing

# %% [markdown]
# It is always a good practice to test the model manually and try to understand what is going on in prediction. Let's choose a single sample out of test set and make the model predict that single image.

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 6))
ax = ax.flatten()

ax[0].imshow(data[-1][0].permute(1, 2, 0))
ax[0].title.set_text(f"{labels_for_viz[data[-1][1]]} (Before Preprocessing)")

ax[1].imshow(test[-1][0].permute(1, 2, 0))
ax[1].title.set_text(f"{labels_for_viz[test[-1][1]]} (After Preprocessing)")
plt.show()

# %% [markdown]
# In the code above, I fetched the last sample of test set and its class is "Healthy". Now, it is time to find out what the probabilities are for each class.

# %%
single_prediction = model.forward((test[-1][0]).to(device).unsqueeze(0))
single_prediction

# %% [markdown]
# Then index of the class with highest probability should be taken for printing the corresponding label.

# %%
single_prediction = int(torch.max(single_prediction, 1)[1])
print("Predicted Class:", labels_for_viz[single_prediction])
